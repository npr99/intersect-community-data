# %% [markdown]
# # Link Job Records with Person Records Files
#
# This notebook attempts to link the Job Records with the Person Records using common variables - age, sex, race, hispan, earnings.
# The link will use the random merge process, starting at the block level and then moving up to Block Group, Tract, and County.

# %% [markdown]
# ## Description of Program
# - program:    ICD_1cv1_LinkJob_HUI_PREC
# - task:       Obtain and clean data for Community Intersection Data.
# - See github commits for description of program updates
# - Current Version:    2022-01-12
# - project:    Interdependent Networked Community Resilience Modeling Environment (IN-CORE)'}, Subtask 5.2 - Social Institutions
# - funding:	  NIST Financial Assistance Award Numbers: 70NANB15H044 and 70NANB20H008
# - author:     Nathanael Rosenheim
#
# - Suggested Citation:
# Rosenheim, N. (2022)'},

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import os # For saving output to path

# %%
# Display versions being used - important information for replication
import sys
print("Python Version     ", sys.version)
print("numpy version:     ", np.__version__)
print("pandas version:    ", pd.__version__)
# Out:
# Python Version      3.8.12 | packaged by conda-forge | (default, Oct 12 2021, 21:22:46) [MSC v.1916 64 bit (AMD64)]
# numpy version:      1.22.2
# pandas version:     1.4.1

# %%
# Store Program Name for output files to have the same name
programname = "ICD_1cv1_LinkJob_HUI_PREC"
# Save Outputfolder - due to long folder name paths output saved to folder with shorter name
# files from this program will be saved with the program name - this helps to follow the overall workflow
outputfolder = "ICD_workflow_2022-01-19"
# Make directory to save output
if not os.path.exists(outputfolder):
    os.mkdir(outputfolder)

# %%
os.getcwd()
# Out:
# 'g:\\Shared drives\\HRRC_IN-CORE\\Tasks\\M5.2-01 Pop inventory\\WorkNPR'

# %% [markdown]
# ### Version of housing unit inventory workflow
#
# Versioning standard based on Semantic Versioning 2.0.0 (https://semver.org/)'},.
#
# Basic overview:
# Given a version number MAJOR.MINOR.PATCH, increment the:
# 1. MAJOR version when you make incompatible API changes,
# 2. MINOR version when you add functionality in a backwards compatible manner, and
# 3. PATCH version when you make backwards compatible bug fixes.
#
# API = application programming interface
#
# How should I deal with revisions in the 0.y.z initial development phase?
#
# The simplest thing to do is start your initial development release at 0.1.0 and then increment the minor version for each subsequent release.
#
# I am going to release the current data using version 0.2.0 or 0-2-0 in the file names. This is an indication of what program generates the data but that the software is not being used in production. I am using the number 2 to indicate that this is the “second” version and that the earlier files released should be considered v0.1.0. The two versions are backwards compatible.

# %%
version = '0.2.0'
version_text = 'v0-2-0'

# %% [markdown]
# ### Setup notebook enviroment to access Cloned Github Package
# This notebook uses packages that are in developement. The packages are available at:
#
# https://github.com/npr99/Labor_Market_Allocation
#
# To replicate this notebook Clone the Github Package to a folder that is a sibling of this notebook.
#
# To access the sibling package you will need to append the parent directory ('..')'}, to the system path list.

# %%
# to access new package that is in a sibling folder - the system path list needs to include the parent folder (..)'},
# append the path of the directory that includes the github repository.
sys.path.append("..\\github_com\\npr99\\Population_Inventory")

# %% [markdown]
# # Setup access to IN-CORE
# https://incore.ncsa.illinois.edu/

# %%
#from pyincore import IncoreClient, Dataset, FragilityService, MappingSet, DataService
#from pyincore_viz.geoutil import GeoUtil as viz

# %% [markdown]
# ### IN-CORE addons
# This program uses coded that is being developed as potential add ons to pyincore. These functions are in a folder called pyincore_addons - this folder is located in the same directory as this notebook.
# The add on functions are organized to mirror the folder sturcture of https://github.com/IN-CORE/pyincore
#
# Each add on function attempts to follow the structure of existing pyincore functions and includes some help information.

# %%
# To reload submodules need to use this magic command to set autoreload on
# %load_ext autoreload
# %autoreload 2
# open, read, and execute python program with reusable commands
from pyincore_data_addons.SourceData.api_census_gov.tidy_censusapi import tidy_censusapi

from pyincore_data_addons.ICD01a_obtain_sourcedata import obtain_sourcedata
from pyincore_data_addons.ICD02a_clean import clean_comm_data_intrsctn
from pyincore_data_addons.ICD04c_linestring_map import wkt_line


from pyincore_data_addons.ICD02b_tidy \
    import icd_tidy as icdtidy

# %% [markdown]
# ## Read In Census data for a County

# %%
#state_counties = {'48167' : 'Galveston County, TX'}
#state_counties = {'37155' : 'Robeson County, NC'}
#state_counties = {'26127' : 'Oceanna County, MI'}
#state_counties = {'48041' : 'Brazos County, TX'}
communities = {'Lumberton_NC' : {
                    'community_name' : 'Lumberton, NC',
                    'counties' : { 
                        1 : {'FIPS Code' : '37155', 'Name' : 'Robeson County, NC'}}},                   
                }

seed = 9876
basevintage = '2010'

# %%
from pyincore_data_addons.ICD02f_intersect_lodes_estab import intersect_lodes_estab

# establishment data is based on data-axel data which is not public
estab_data_folder_path = 'C:\\MyProjects\\HRRCProjects\\IN-CORE\\WorkNPR\\'
lodes_file_name = "joblist_v010_JT07_37155_2010_rs133234_prechui.csv"
posted_relative_path = '\\..\\Posted\\Labor_Market_Allocation_Output'
# Merge job records with establishment location data
jrec_estab_df = intersect_lodes_estab(communities=communities,
                                outputfolder = outputfolder,
                                seed = seed,
                                basevintage = basevintage,
                                estab_data_folder_path = estab_data_folder_path,
                                lodes_file_name = lodes_file_name,
                                posted_relative_path = posted_relative_path)
# Out:
# Intersect Community Data for: Lumberton, NC
# Robeson County, NC : county FIPS Code 37155
# File g:\Shared drives\HRRC_IN-CORE\Tasks\M5.2-01 Pop inventory\WorkNPR/ICD_workflow_2022-01-19/RobesonCounty_NC/01_SourceData/dataaxle_01a_obtain_37155_2010.csv Already exists - Skipping Obtain data-axel.
# ******************************
#  Spatial Join Establishments with blocks
# ******************************
# 10 Establishments have missing block data
# Double check to ensure that missing block data is due to
# establishment geocode being just outside of county boundary.
# ******************************
#  Expand Dataset
# ******************************
#      Add Counter
#      Generate unique ID
#      Counter max length 4
# ******************************
#  Read in LODES Dataset
# ******************************
#
# ***************************************
#     Random merge between Job Records and Establishment.
# ***************************************
#
# File ICD_workflow_2022-01-19/RobesonCounty_NC/04_RandomMerge/jrec_randomestab_37155_2010_rs9876_primary.csv Already exists - Skipping Random Merge.
# File jrec_randomestab_37155_2010_rs9876_secondary Already exists - Skipping Random Merge.

# %%
jrec_estab_df['primary'].head(1).T
# Out:
#                                                                         0
# jobid                   WB371559601021075HB371419206021018jidodJT07212...
# County2010                                                          37155
# Tract2010                                                     37155960102
# BlockGroup2010                                               371559601021
# Block2010                                                 371559601021075
# ...                                                                   ...
# Longitude                                                       -78.98466
# NAICS2D                                                                44
# NAICS4D                                                              4453
# SIName                                                                NaN
# Employee_Size_Location                                                6.0
#
# [61 rows x 1 columns]

# %%
from pyincore_data_addons.ICD02c_intersect_prechui_nces import intersect_prechui_nces



# Merge person records with National Center for Education Statistics Data
prechui_srec_df = intersect_prechui_nces(communities=communities,
                                outputfolder = outputfolder,
                                seed = seed,
                                basevintage = basevintage)
# Out:
# Intersect Community Data for: Lumberton, NC
# Robeson County, NC : county FIPS Code 37155
#     Obtaining Housing Unit Inventory and Person Records for Lumberton, NC
#      Robeson County, NC : county FIPS Code 37155
# File ICD_workflow_2022-01-19/RobesonCounty_NC/02_TidySourceData/nces_tidy_ccd_37155_09.csv Already exists - Skipping Tidy NCES.
#
# ***************************************
#     Random merge between Person Records and Student records.
# ***************************************
#
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: ncessch_1
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge students on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_1', 'gradelevel1', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# Initializing primary flag set variable for NCESSCH
# New flag: NCESSCH_flagsetrm
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus']
# Initializing geovar flag set variable for NCESSCH at geolevel ncessch_1
# New flag: NCESSCH_ncessch_1_flagsetrm
# Observations without primary flag set 134168
# Observations without geovar flag set 134168
# After updated observations without geovar flag set 134168
# Setting 134168 flags for data without NCESSCH before merge.
# 0 observations do not have required variable ncessch_1
# 97021 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 0 flags for observations without required variable ncessch_1
# Setting 97021 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 37147 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_1', 'gradelevel1', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_1', 'gradelevel1', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# Initializing primary flag set variable for NCESSCH
# New flag: NCESSCH_flagsetrm
# ['srecid', 'index', 'NCESSCH', 'SCHNAM09', 'LEVEL09', 'CHARTR09', 'LATCOD09', 'LONCOD09', 'racecat5', 'race', 'hispan', 'sex', 'gradelevel', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3']
# Initializing geovar flag set variable for NCESSCH at geolevel ncessch_1
# New flag: NCESSCH_ncessch_1_flagsetrm
# Observations without primary flag set 24024
# Observations without geovar flag set 24024
# After updated observations without geovar flag set 24024
# Setting 24024 flags for NCESSCH secondary data not used.
# 12059 observations do not have required variable ncessch_1
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 12059 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 11965 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_1', 'gradelevel1', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_1', 'gradelevel1', 'sex', 'racecat5']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_1', 'gradelevel1', 'sex', 'racecat5', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 27157
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 1975
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_1', 'gradelevel1', 'sex', 'racecat5', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Observations without primary flag set 39122
# Observations without geovar flag set 39122
# After updated observations without geovar flag set 39122
# Round = 1
# Setting 9990 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_1
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 0 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Observations geovar flag set 1 = 9990
# After Recombime flag set 1 = 9990
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Before update output_df observations flag set 1 = 0
# Before update results observations flag set 1 = 9990
# After update observations geovar flag set 1 = 9990
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_1_flagsetrm
# Observations flag not equal to 0 107011
# Input and output data have the same length 134168
# Outputdata has 107011 Observations with predicted NCESSCH
# Percent left to predict: 20.24
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Before update output_df observations flag set 1 = 0
# Before update results observations flag set 1 = 9990
# After update observations geovar flag set 1 = 9990
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_1_flagsetrm
# Observations flag not equal to 0 22049
# Input and output data have the same length 24024
# Outputdata has 22049 Observations with predicted NCESSCH
# Percent left to predict:  8.22
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  20.241041
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Attempt to merge students without racecat5.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_1', 'gradelevel1', 'sex']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Observations without primary flag set 124178
# Observations without geovar flag set 27157
# After updated observations without geovar flag set 27157
# Setting 0 flags for NCESSCH set before random merge.
# 0 observations do not have required variable ncessch_1
# 97021 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# Setting 0 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Attempting random merge for 27157 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_1', 'gradelevel1', 'sex', 'random_order']
# Generating random merge order by ['ncessch_1', 'gradelevel1', 'sex']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 14034
# Observations without geovar flag set 1975
# After updated observations without geovar flag set 1975
# Setting 1975 flags for NCESSCH secondary data not used.
# 12059 observations do not have required variable ncessch_1
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# Setting 0 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Attempting random merge for 1975 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_1', 'gradelevel1', 'sex', 'random_order']
# Generating random merge order by ['ncessch_1', 'gradelevel1', 'sex']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_1', 'gradelevel1', 'sex', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 26211
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 1029
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_1', 'gradelevel1', 'sex', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Observations without primary flag set 28186
# Observations without geovar flag set 28186
# After updated observations without geovar flag set 28186
# Round = 2
# Setting 946 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_1
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# Setting 0 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Observations geovar flag set 2 = 946
# After Recombime flag set 2 = 946
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Before update output_df observations flag set 2 = 0
# Before update results observations flag set 2 = 946
# After update observations geovar flag set 2 = 946
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_1_flagsetrm
# Observations flag not equal to 0 107957
# Input and output data have the same length 134168
# Outputdata has 107957 Observations with predicted NCESSCH
# Percent left to predict: 19.54
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Before update output_df observations flag set 2 = 0
# Before update results observations flag set 2 = 946
# After update observations geovar flag set 2 = 946
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_1_flagsetrm
# Observations flag not equal to 0 22995
# Input and output data have the same length 24024
# Outputdata has 22995 Observations with predicted NCESSCH
# Percent left to predict:  4.28
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  19.535955
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Attempt to merge students without sex.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_1', 'gradelevel1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 123232
# Observations without geovar flag set 26211
# After updated observations without geovar flag set 26211
# Setting 0 flags for NCESSCH set before random merge.
# 0 observations do not have required variable ncessch_1
# 97021 observations do not have required variable gradelevel1
# Setting 0 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Attempting random merge for 26211 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_1', 'gradelevel1', 'random_order']
# Generating random merge order by ['ncessch_1', 'gradelevel1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 13088
# Observations without geovar flag set 1029
# After updated observations without geovar flag set 1029
# Setting 1029 flags for NCESSCH secondary data not used.
# 12059 observations do not have required variable ncessch_1
# 0 observations do not have required variable gradelevel1
# Setting 0 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Attempting random merge for 1029 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_1', 'gradelevel1', 'random_order']
# Generating random merge order by ['ncessch_1', 'gradelevel1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_1', 'gradelevel1', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 26008
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 826
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_1', 'gradelevel1', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Observations without primary flag set 27037
# Observations without geovar flag set 27037
# After updated observations without geovar flag set 27037
# Round = 3
# Setting 203 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_1
# 0 observations do not have required variable gradelevel1
# Setting 0 flags for observations without required variable ncessch_1
# Setting 0 flags for observations without required variable gradelevel1
# Observations geovar flag set 3 = 203
# After Recombime flag set 3 = 203
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Before update output_df observations flag set 3 = 0
# Before update results observations flag set 3 = 203
# After update observations geovar flag set 3 = 203
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_1_flagsetrm
# Observations flag not equal to 0 108160
# Input and output data have the same length 134168
# Outputdata has 108160 Observations with predicted NCESSCH
# Percent left to predict: 19.38
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm']
# Before update output_df observations flag set 3 = 0
# Before update results observations flag set 3 = 203
# After update observations geovar flag set 3 = 203
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_1_flagsetrm
# Observations flag not equal to 0 23198
# Input and output data have the same length 24024
# Outputdata has 23198 Observations with predicted NCESSCH
# Percent left to predict:  3.44
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  19.384652
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: ncessch_2
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge students on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_2', 'gradelevel1', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Initializing geovar flag set variable for NCESSCH at geolevel ncessch_2
# New flag: NCESSCH_ncessch_2_flagsetrm
# Observations without primary flag set 123029
# Observations without geovar flag set 134168
# After updated observations without geovar flag set 123029
# Setting 0 flags for NCESSCH set before random merge.
# 22023 observations do not have required variable ncessch_2
# 97021 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 19172 flags for observations without required variable ncessch_2
# Setting 97021 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 22659 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_2', 'gradelevel1', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_2', 'gradelevel1', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Initializing geovar flag set variable for NCESSCH at geolevel ncessch_2
# New flag: NCESSCH_ncessch_2_flagsetrm
# Observations without primary flag set 12885
# Observations without geovar flag set 24024
# After updated observations without geovar flag set 12885
# Setting 12885 flags for NCESSCH secondary data not used.
# 18740 observations do not have required variable ncessch_2
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 7601 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 5284 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_2', 'gradelevel1', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_2', 'gradelevel1', 'sex', 'racecat5']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_2', 'gradelevel1', 'sex', 'racecat5', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 18579
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 1204
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_2', 'gradelevel1', 'sex', 'racecat5', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Observations without primary flag set 23863
# Observations without geovar flag set 23863
# After updated observations without geovar flag set 23863
# Round = 4
# Setting 4080 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_2
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 0 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Observations geovar flag set 4 = 4080
# After Recombime flag set 4 = 4080
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Before update output_df observations flag set 4 = 0
# Before update results observations flag set 4 = 4080
# After update observations geovar flag set 4 = 4080
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_2_flagsetrm
# Observations flag not equal to 0 115589
# Input and output data have the same length 134168
# Outputdata has 115589 Observations with predicted NCESSCH
# Percent left to predict: 13.85
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Before update output_df observations flag set 4 = 0
# Before update results observations flag set 4 = 4080
# After update observations geovar flag set 4 = 4080
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_2_flagsetrm
# Observations flag not equal to 0 22820
# Input and output data have the same length 24024
# Outputdata has 22820 Observations with predicted NCESSCH
# Percent left to predict:  5.01
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  13.847564
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Attempt to merge students without racecat5.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_2', 'gradelevel1', 'sex']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 118949
# Observations without geovar flag set 18579
# After updated observations without geovar flag set 18579
# Setting 0 flags for NCESSCH set before random merge.
# 22023 observations do not have required variable ncessch_2
# 97021 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# Setting 0 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Attempting random merge for 18579 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_2', 'gradelevel1', 'sex', 'random_order']
# Generating random merge order by ['ncessch_2', 'gradelevel1', 'sex']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 8805
# Observations without geovar flag set 1204
# After updated observations without geovar flag set 1204
# Setting 1204 flags for NCESSCH secondary data not used.
# 18740 observations do not have required variable ncessch_2
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# Setting 0 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Attempting random merge for 1204 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_2', 'gradelevel1', 'sex', 'random_order']
# Generating random merge order by ['ncessch_2', 'gradelevel1', 'sex']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_2', 'gradelevel1', 'sex', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 18212
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 837
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_2', 'gradelevel1', 'sex', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Observations without primary flag set 19416
# Observations without geovar flag set 19416
# After updated observations without geovar flag set 19416
# Round = 5
# Setting 367 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_2
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# Setting 0 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Observations geovar flag set 5 = 367
# After Recombime flag set 5 = 367
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Before update output_df observations flag set 5 = 0
# Before update results observations flag set 5 = 367
# After update observations geovar flag set 5 = 367
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_2_flagsetrm
# Observations flag not equal to 0 115956
# Input and output data have the same length 134168
# Outputdata has 115956 Observations with predicted NCESSCH
# Percent left to predict: 13.57
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Before update output_df observations flag set 5 = 0
# Before update results observations flag set 5 = 367
# After update observations geovar flag set 5 = 367
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_2_flagsetrm
# Observations flag not equal to 0 23187
# Input and output data have the same length 24024
# Outputdata has 23187 Observations with predicted NCESSCH
# Percent left to predict:  3.48
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  13.574027
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Attempt to merge students without sex.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_2', 'gradelevel1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 118582
# Observations without geovar flag set 18212
# After updated observations without geovar flag set 18212
# Setting 0 flags for NCESSCH set before random merge.
# 22023 observations do not have required variable ncessch_2
# 97021 observations do not have required variable gradelevel1
# Setting 0 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Attempting random merge for 18212 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_2', 'gradelevel1', 'random_order']
# Generating random merge order by ['ncessch_2', 'gradelevel1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 8438
# Observations without geovar flag set 837
# After updated observations without geovar flag set 837
# Setting 837 flags for NCESSCH secondary data not used.
# 18740 observations do not have required variable ncessch_2
# 0 observations do not have required variable gradelevel1
# Setting 0 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Attempting random merge for 837 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_2', 'gradelevel1', 'random_order']
# Generating random merge order by ['ncessch_2', 'gradelevel1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_2', 'gradelevel1', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 18127
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 752
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_2', 'gradelevel1', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Observations without primary flag set 18964
# Observations without geovar flag set 18964
# After updated observations without geovar flag set 18964
# Round = 6
# Setting 85 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_2
# 0 observations do not have required variable gradelevel1
# Setting 0 flags for observations without required variable ncessch_2
# Setting 0 flags for observations without required variable gradelevel1
# Observations geovar flag set 6 = 85
# After Recombime flag set 6 = 85
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Before update output_df observations flag set 6 = 0
# Before update results observations flag set 6 = 85
# After update observations geovar flag set 6 = 85
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_2_flagsetrm
# Observations flag not equal to 0 116041
# Input and output data have the same length 134168
# Outputdata has 116041 Observations with predicted NCESSCH
# Percent left to predict: 13.51
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm']
# Before update output_df observations flag set 6 = 0
# Before update results observations flag set 6 = 85
# After update observations geovar flag set 6 = 85
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_2_flagsetrm
# Observations flag not equal to 0 23272
# Input and output data have the same length 24024
# Outputdata has 23272 Observations with predicted NCESSCH
# Percent left to predict:  3.13
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  13.510673
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: ncessch_3
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge students on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_3', 'gradelevel1', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Initializing geovar flag set variable for NCESSCH at geolevel ncessch_3
# New flag: NCESSCH_ncessch_3_flagsetrm
# Observations without primary flag set 118497
# Observations without geovar flag set 134168
# After updated observations without geovar flag set 118497
# Setting 0 flags for NCESSCH set before random merge.
# 0 observations do not have required variable ncessch_3
# 97021 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 0 flags for observations without required variable ncessch_3
# Setting 97021 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 21476 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_3', 'gradelevel1', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_3', 'gradelevel1', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Initializing geovar flag set variable for NCESSCH at geolevel ncessch_3
# New flag: NCESSCH_ncessch_3_flagsetrm
# Observations without primary flag set 8353
# Observations without geovar flag set 24024
# After updated observations without geovar flag set 8353
# Setting 8353 flags for NCESSCH secondary data not used.
# 17249 observations do not have required variable ncessch_3
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 1578 flags for observations without required variable ncessch_3
# Setting 0 flags for observations without required variable gradelevel1
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 6775 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_3', 'gradelevel1', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_3', 'gradelevel1', 'sex', 'racecat5']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_3', 'gradelevel1', 'sex', 'racecat5', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 15369
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 668
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_3', 'gradelevel1', 'sex', 'racecat5', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm']
# Observations without primary flag set 22144
# Observations without geovar flag set 22144
# After updated observations without geovar flag set 22144
# Round = 7
# Setting 6107 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_3
# 0 observations do not have required variable gradelevel1
# 0 observations do not have required variable sex
# ...
# Percent left to predict:  0.06
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:   1.192535
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Attempt to merge students without sex.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_5', 'gradelevel3']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 111048
# Observations without geovar flag set 1600
# After updated observations without geovar flag set 1600
# Setting 0 flags for NCESSCH set before random merge.
# 111807 observations do not have required variable ncessch_5
# 97021 observations do not have required variable gradelevel3
# Setting 0 flags for observations without required variable ncessch_5
# Setting 0 flags for observations without required variable gradelevel3
# Attempting random merge for 1600 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_5', 'gradelevel3', 'random_order']
# Generating random merge order by ['ncessch_5', 'gradelevel3']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 904
# Observations without geovar flag set 14
# After updated observations without geovar flag set 14
# Setting 14 flags for NCESSCH secondary data not used.
# 23422 observations do not have required variable ncessch_5
# 0 observations do not have required variable gradelevel3
# Setting 0 flags for observations without required variable ncessch_5
# Setting 0 flags for observations without required variable gradelevel3
# Attempting random merge for 14 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_5', 'gradelevel3', 'random_order']
# Generating random merge order by ['ncessch_5', 'gradelevel3']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_5', 'gradelevel3', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 1598
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 12
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_5', 'gradelevel3', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm']
# Observations without primary flag set 1612
# Observations without geovar flag set 1612
# After updated observations without geovar flag set 1612
# Round = 12
# Setting 2 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_5
# 0 observations do not have required variable gradelevel3
# Setting 0 flags for observations without required variable ncessch_5
# Setting 0 flags for observations without required variable gradelevel3
# Observations geovar flag set 12 = 2
# After Recombime flag set 12 = 2
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm']
# Before update output_df observations flag set 12 = 4
# Before update results observations flag set 12 = 2
# After update observations geovar flag set 12 = 6
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_5_flagsetrm
# Observations flag not equal to 0 132570
# Input and output data have the same length 134168
# Outputdata has 132570 Observations with predicted NCESSCH
# Percent left to predict:  1.19
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm']
# Before update output_df observations flag set 12 = 4
# Before update results observations flag set 12 = 2
# After update observations geovar flag set 12 = 6
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_5_flagsetrm
# Observations flag not equal to 0 24012
# Input and output data have the same length 24024
# Outputdata has 24012 Observations with predicted NCESSCH
# Percent left to predict:  0.05
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:   1.191044
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: ncessch_6
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge students on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['ncessch_6', 'gradelevel3', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'huid', 'pernum', 'Block2010str', 'Block2010', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'PLCGEOID10', 'PLCNAME10', 'PUMGEOID10', 'rppnt4269', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'racecat5', 'BLOCKID10', 'ncessch_3', 'high_schnm', 'ncessch_2', 'mid_schnm', 'ncessch_1', 'primary_schnm', 'ncessch_5', 'overalsab_schnm', 'ncessch_6', 'charter_schnm', 'CommunityFocus', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 111046
# Observations without geovar flag set 7605
# After updated observations without geovar flag set 7605
# Setting 0 flags for NCESSCH set before random merge.
# 63738 observations do not have required variable ncessch_6
# 97021 observations do not have required variable gradelevel3
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 0 flags for observations without required variable ncessch_6
# Setting 0 flags for observations without required variable gradelevel3
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 7605 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['ncessch_6', 'gradelevel3', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_6', 'gradelevel3', 'sex', 'racecat5']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Checking primary key name srecid
# Primary key variable srecid is unique.
# Primary key srecid has no missing values
# ['srecid', 'index', 'LEVEL09', 'CHARTR09', 'racecat5', 'race', 'hispan', 'sex', 'srec_counter', 'ncessch_1', 'ncessch_2', 'ncessch_3', 'ncessch_4', 'ncessch_5', 'ncessch_6', 'gradelevel1', 'gradelevel2', 'gradelevel3', 'NCESSCH', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09']
# Observations without primary flag set 902
# Observations without geovar flag set 0
# After updated observations without geovar flag set 0
# Setting 0 flags for NCESSCH secondary data not used.
# 23915 observations do not have required variable ncessch_6
# 0 observations do not have required variable gradelevel3
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 0 flags for observations without required variable ncessch_6
# Setting 0 flags for observations without required variable gradelevel3
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Attempting random merge for 0 secondary observations.
# Warning: NA dataframe has length 0
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['srecid']
# Sorting before random merge order by ['ncessch_6', 'gradelevel3', 'sex', 'racecat5', 'random_order']
# Generating random merge order by ['ncessch_6', 'gradelevel3', 'sex', 'racecat5']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['ncessch_6', 'gradelevel3', 'sex', 'racecat5', 'random_mergeorder']
# Primary data frame has extra NCESSCH  observations with no match: 7605
# Observations with no match filled with -999
# Merge found extra NCESSCH  observations: 0
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'ncessch_6', 'gradelevel3', 'sex', 'racecat5', 'random_mergeorder', 'srecid', 'NCESSCH', 'SCHNAM09', 'gradelevel', 'LATCOD09', 'LONCOD09', 'check_merge', 'NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm']
# Observations without primary flag set 7605
# Observations without geovar flag set 7605
# After updated observations without geovar flag set 7605
# Round = 13
# Setting 0 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable ncessch_6
# 0 observations do not have required variable gradelevel3
# 0 observations do not have required variable sex
# 0 observations do not have required variable racecat5
# Setting 0 flags for observations without required variable ncessch_6
# Setting 0 flags for observations without required variable gradelevel3
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable racecat5
# Observations geovar flag set 13 = 0
# After Recombime flag set 13 = 0
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm']
# Before update output_df observations flag set 13 = 96
# Before update results observations flag set 13 = 0
# After update observations geovar flag set 13 = 96
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_6_flagsetrm
# Observations flag not equal to 0 126563
# Input and output data have the same length 134168
# Outputdata has 126563 Observations with predicted NCESSCH
# Percent left to predict:  5.67
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['NCESSCH_flagsetrm', 'NCESSCH_ncessch_1_flagsetrm', 'NCESSCH_ncessch_2_flagsetrm', 'NCESSCH_ncessch_3_flagsetrm', 'NCESSCH_ncessch_5_flagsetrm', 'NCESSCH_ncessch_6_flagsetrm']
# Before update output_df observations flag set 13 = 96
# Before update results observations flag set 13 = 0
# After update observations geovar flag set 13 = 96
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag NCESSCH_ncessch_6_flagsetrm
# Observations flag not equal to 0 24024
# Input and output data have the same length 24024
# Outputdata has 24024 Observations with predicted NCESSCH
# Percent left to predict:  0.00
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:   5.668267
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     All secondary data has been used.
#     All secondary will not be reused.
# ***************************************
#
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
#
# ***************************************
#     Try to polish final prechui srec data.
# ***************************************
#
#
# ***************************************
#     Save cleaned data file.
# ***************************************
#
# File saved: g:\Shared drives\HRRC_IN-CORE\Tasks\M5.2-01 Pop inventory\WorkNPR/ICD_workflow_2022-01-19/RobesonCounty_NC/prechui_srec_v0-2-0_37155_2010_rs9876.csv

# %%
prechui_srec_df['primary'].head(1).T
# Out:
#                                                                         0
# precid                                              B371559601011002P0002
# huid                                                 B371559601011002H001
# pernum                                                                  1
# Block2010str                                             B371559601011002
# Block2010                                                 371559601011002
# Tract2010                                                     37155960101
# sex                                                                     1
# race                                                                  2.0
# hispan                                                                0.0
# randageP12                                                           62.0
# agegroupP12                                                          17.0
# randagePCT12                                                         64.0
# agegroupP43                                                           2.0
# agegroupH18                                                           2.0
# agegroupH17                                                           6.0
# child                                                                 0.0
# gqtype                                                                0.0
# numprec                                                               2.0
# family                                                                1.0
# PLCGEOID10                                                            NaN
# PLCNAME10                                                  Unincorporated
# PUMGEOID10                                                        3705100
# rppnt4269                           POINT (-78.94751707644164 34.9055645)
# gradelevel1                                                           NaN
# gradelevel2                                                           NaN
# gradelevel3                                                           NaN
# racecat5                                                              4.0
# BLOCKID10                                                 371559601011002
# ncessch_3                                                    370393002244
# high_schnm                                               Saint Pauls High
# ncessch_2                                                             NaN
# mid_schnm                                            No Middle School SAB
# ncessch_1                                                    370393001577
# primary_schnm                                          Parkton Elementary
# ncessch_5                                                             NaN
# overalsab_schnm                                                       NaN
# ncessch_6                                                             NaN
# charter_schnm                                                         NaN
# CommunityFocus                                          Outside Community
# NCESSCH                                                               NaN
# NCESSCH_flagsetrm                                                     0.0
# NCESSCH_ncessch_1_flagsetrm                                        -888.0
# NCESSCH_ncessch_2_flagsetrm                                        -888.0
# NCESSCH_ncessch_3_flagsetrm                                        -888.0
# NCESSCH_ncessch_5_flagsetrm                                        -888.0
# NCESSCH_ncessch_6_flagsetrm                                        -888.0
# SCHNAM09                                                              NaN
# gradelevel                                                            NaN
# LATCOD09                                                              NaN
# LONCOD09                                                              NaN
# geometry                     POINT (-78.94751616135665 34.90556159883747)
# geocode_type                                                          hcb
# hcb_lon                                                        -78.947516
# hcb_lat                                                         34.905562

# %%
from pyincore_data_addons.ICD03a_results_table import pop_results_table as viz
viz.pop_results_table(prechui_srec_df['primary'],
                who = "Total Population by Persons", 
                what = "by Gradelevel",
                where = "Robeson County, NC",
                when = "2010",
                row_index = 'gradelevel',
                col_index = 'CommunityFocus')
                #row_percent = "1 Family Household")
# Out:
# ['Inside Community', 'Outside Community', 'Total Population by Persons']
# <style type="text/css">
# #T_fa045 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_fa045">
#   <caption>Table. Total Population by Persons by Gradelevel, Robeson County, NC, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >CommunityFocus</th>
#       <th id="T_fa045_level0_col0" class="col_heading level0 col0" >Inside Community (%)</th>
#       <th id="T_fa045_level0_col1" class="col_heading level0 col1" >Outside Community (%)</th>
#       <th id="T_fa045_level0_col2" class="col_heading level0 col2" >Total Population by Persons (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gradelevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa045_level0_row0" class="row_heading level0 row0" >G01</th>
#       <td id="T_fa045_row0_col0" class="data row0 col0" >274	 (7.3%)</td>
#       <td id="T_fa045_row0_col1" class="data row0 col1" >1,528	 (7.9%)</td>
#       <td id="T_fa045_row0_col2" class="data row0 col2" >1,802	 (7.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row1" class="row_heading level0 row1" >G02</th>
#       <td id="T_fa045_row1_col0" class="data row1 col0" >281	 (7.5%)</td>
#       <td id="T_fa045_row1_col1" class="data row1 col1" >1,485	 (7.7%)</td>
#       <td id="T_fa045_row1_col2" class="data row1 col2" >1,766	 (7.6%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row2" class="row_heading level0 row2" >G03</th>
#       <td id="T_fa045_row2_col0" class="data row2 col0" >307	 (8.2%)</td>
#       <td id="T_fa045_row2_col1" class="data row2 col1" >1,544	 (8.0%)</td>
#       <td id="T_fa045_row2_col2" class="data row2 col2" >1,851	 (8.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row3" class="row_heading level0 row3" >G04</th>
#       <td id="T_fa045_row3_col0" class="data row3 col0" >310	 (8.2%)</td>
#       <td id="T_fa045_row3_col1" class="data row3 col1" >1,627	 (8.4%)</td>
#       <td id="T_fa045_row3_col2" class="data row3 col2" >1,937	 (8.4%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row4" class="row_heading level0 row4" >G05</th>
#       <td id="T_fa045_row4_col0" class="data row4 col0" >301	 (8.0%)</td>
#       <td id="T_fa045_row4_col1" class="data row4 col1" >1,543	 (8.0%)</td>
#       <td id="T_fa045_row4_col2" class="data row4 col2" >1,844	 (8.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row5" class="row_heading level0 row5" >G06</th>
#       <td id="T_fa045_row5_col0" class="data row5 col0" >289	 (7.7%)</td>
#       <td id="T_fa045_row5_col1" class="data row5 col1" >1,543	 (8.0%)</td>
#       <td id="T_fa045_row5_col2" class="data row5 col2" >1,832	 (7.9%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row6" class="row_heading level0 row6" >G07</th>
#       <td id="T_fa045_row6_col0" class="data row6 col0" >311	 (8.3%)</td>
#       <td id="T_fa045_row6_col1" class="data row6 col1" >1,433	 (7.4%)</td>
#       <td id="T_fa045_row6_col2" class="data row6 col2" >1,744	 (7.5%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row7" class="row_heading level0 row7" >G08</th>
#       <td id="T_fa045_row7_col0" class="data row7 col0" >287	 (7.6%)</td>
#       <td id="T_fa045_row7_col1" class="data row7 col1" >1,351	 (7.0%)</td>
#       <td id="T_fa045_row7_col2" class="data row7 col2" >1,638	 (7.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row8" class="row_heading level0 row8" >G09</th>
#       <td id="T_fa045_row8_col0" class="data row8 col0" >294	 (7.8%)</td>
#       <td id="T_fa045_row8_col1" class="data row8 col1" >1,767	 (9.1%)</td>
#       <td id="T_fa045_row8_col2" class="data row8 col2" >2,061	 (8.9%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row9" class="row_heading level0 row9" >G10</th>
#       <td id="T_fa045_row9_col0" class="data row9 col0" >307	 (8.2%)</td>
#       <td id="T_fa045_row9_col1" class="data row9 col1" >1,496	 (7.7%)</td>
#       <td id="T_fa045_row9_col2" class="data row9 col2" >1,803	 (7.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row10" class="row_heading level0 row10" >G11</th>
#       <td id="T_fa045_row10_col0" class="data row10 col0" >253	 (6.7%)</td>
#       <td id="T_fa045_row10_col1" class="data row10 col1" >1,177	 (6.1%)</td>
#       <td id="T_fa045_row10_col2" class="data row10 col2" >1,430	 (6.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row11" class="row_heading level0 row11" >G12</th>
#       <td id="T_fa045_row11_col0" class="data row11 col0" >210	 (5.6%)</td>
#       <td id="T_fa045_row11_col1" class="data row11 col1" >1,072	 (5.5%)</td>
#       <td id="T_fa045_row11_col2" class="data row11 col2" >1,282	 (5.5%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row12" class="row_heading level0 row12" >KG</th>
#       <td id="T_fa045_row12_col0" class="data row12 col0" >279	 (7.4%)</td>
#       <td id="T_fa045_row12_col1" class="data row12 col1" >1,353	 (7.0%)</td>
#       <td id="T_fa045_row12_col2" class="data row12 col2" >1,632	 (7.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row13" class="row_heading level0 row13" >PK</th>
#       <td id="T_fa045_row13_col0" class="data row13 col0" >61	 (1.6%)</td>
#       <td id="T_fa045_row13_col1" class="data row13 col1" >439	 (2.3%)</td>
#       <td id="T_fa045_row13_col2" class="data row13 col2" >500	 (2.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_fa045_level0_row14" class="row_heading level0 row14" >Total</th>
#       <td id="T_fa045_row14_col0" class="data row14 col0" >3,764	 (100.0%)</td>
#       <td id="T_fa045_row14_col1" class="data row14 col1" >19,358	 (100.0%)</td>
#       <td id="T_fa045_row14_col2" class="data row14 col2" >23,122	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pyincore_data_addons.ICD02d_intersect_prechui_lodes import intersect_prechui_lodes

seed = 9876
basevintage = '2010'
lodes_file_name = "joblist_v010_JT07_37155_2010_rs133234_prechui.csv"
posted_relative_path = '\\..\\Posted\\Labor_Market_Allocation_Output'

# Merge person records with National Center for Education Statistics Data
prechui_lodes_df  = intersect_prechui_lodes(communities=communities,
                                outputfolder = outputfolder,
                                seed = seed,
                                basevintage = basevintage,
                                lodes_file_name = lodes_file_name,
                                posted_relative_path = posted_relative_path)
# Out:
# Intersect Community Data for: Lumberton, NC
# Robeson County, NC : county FIPS Code 37155
#     Obtaining Housing Unit Inventory and Person Records for Lumberton, NC
#      Robeson County, NC : county FIPS Code 37155
# ******************************
#  Read in LODES Dataset
# ******************************
#
# ***************************************
#     Try to clean geometry lat lon.
# ***************************************
#
# ******************************
#  Split LODES Dataset
#  To append workers that live outside of county to Prechui
# ******************************
# C:\Users\nathanael99\Miniconda3\envs\pyincoreEnv20220106\lib\site-packages\geopandas\geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\nathanael99\Miniconda3\envs\pyincoreEnv20220106\lib\site-packages\geopandas\geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\nathanael99\Miniconda3\envs\pyincoreEnv20220106\lib\site-packages\geopandas\geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# ******************************
#  Prepare LODES Dataset for Merge.
#  Merge workers with persons living in county.
# ******************************
#
# ***************************************
#     Random merge between Person Records and Jobs.
# ***************************************
#
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge householder                         on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Tract2010', 'Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# Initializing primary flag set variable for jobid
# New flag: jobid_flagsetrm
# ['precid', 'Block2010', 'huid', 'pernum', 'Block2010str', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'agegroupLODES', 'PossibleWorker', 'EstTotalWorkers1', 'EstTotalWorkers2', 'EstTotalWorkers3', 'randincome', 'randAnnualEarnings1', 'randMonthEarnings1', 'earngingsgroupLODES1', 'randAnnualEarnings2', 'randMonthEarnings2', 'earngingsgroupLODES2', 'randAnnualEarnings3', 'randMonthEarnings3', 'earngingsgroupLODES3']
# Initializing geovar flag set variable for jobid at geolevel Block2010
# New flag: jobid_Block2010_flagsetrm
# Observations without primary flag set 134168
# Observations without geovar flag set 134168
# After updated observations without geovar flag set 134168
# Setting 134168 flags for data without jobid before merge.
# 0 observations do not have required variable Block2010
# 7970 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable Block2010
# Setting 7970 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 126198 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name uniqueid_part1
# Primary key variable uniqueid_part1 is unique.
# Primary key uniqueid_part1 has no missing values
# Initializing primary flag set variable for jobid
# New flag: jobid_flagsetrm
# ['uniqueid_part1', 'Block2010', 'jobid', 'race', 'sex', 'hispan', 'agegroupLODES', 'IndustryCode', 'w_geometry', 'wcb_lat', 'wcb_lon', 'h_stabbr', 'Earnings', 'Education', 'jobtype', 'od_distance', 'earngingsgroupLODES1', 'earngingsgroupLODES2', 'earngingsgroupLODES3']
# Initializing geovar flag set variable for jobid at geolevel Block2010
# New flag: jobid_Block2010_flagsetrm
# Observations without primary flag set 6062
# Observations without geovar flag set 6062
# After updated observations without geovar flag set 6062
# Setting 6062 flags for jobid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 6062 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['uniqueid_part1']
# Sorting before random merge order by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder']
# Primary data frame has extra jobid  observations with no match: 123534
# Observations with no match filled with -999
# Merge found extra jobid  observations: 3398
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder', 'uniqueid_part1', 'jobid', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance', 'check_merge', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm']
# Observations without primary flag set 129596
# Observations without geovar flag set 129596
# After updated observations without geovar flag set 129596
# Round = 1
# Setting 2664 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Observations geovar flag set 1 = 2664
# After Recombime flag set 1 = 2664
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 0
# Before update results observations flag set 1 = 2664
# After update observations geovar flag set 1 = 2664
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag jobid_Block2010_flagsetrm
# Observations flag not equal to 0 10634
# Input and output data have the same length 134168
# Outputdata has 10634 Observations with predicted jobid
# Percent left to predict: 92.07
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 0
# Before update results observations flag set 1 = 2664
# After update observations geovar flag set 1 = 2664
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag jobid_Block2010_flagsetrm
# Observations flag not equal to 0 2664
# Input and output data have the same length 6062
# Outputdata has 2664 Observations with predicted jobid
# Percent left to predict: 56.05
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  92.074116
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: BlockGroup
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge householder                         on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['BlockGroup2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Tract2010', 'Block2010']
# Adding BlockGroup2010 expected length 12
# Dataframe has Block 2010 for new geovar BlockGroup2010
# Confirming BlockGroup2010 has expected length.
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'BlockGroup2010', 'Block2010', 'huid', 'pernum', 'Block2010str', 'Tract2010', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'agegroupLODES', 'PossibleWorker', 'EstTotalWorkers1', 'EstTotalWorkers2', 'EstTotalWorkers3', 'randincome', 'randAnnualEarnings1', 'randMonthEarnings1', 'earngingsgroupLODES1', 'randAnnualEarnings2', 'randMonthEarnings2', 'earngingsgroupLODES2', 'randAnnualEarnings3', 'randMonthEarnings3', 'earngingsgroupLODES3', 'jobid', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm']
# Initializing geovar flag set variable for jobid at geolevel BlockGroup2010
# New flag: jobid_BlockGroup2010_flagsetrm
# Observations without primary flag set 131504
# Observations without geovar flag set 134168
# After updated observations without geovar flag set 131504
# Setting 0 flags for jobid set before random merge.
# 0 observations do not have required variable BlockGroup2010
# 7970 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable BlockGroup2010
# Setting 7970 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 123534 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['BlockGroup2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['BlockGroup2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding BlockGroup2010 expected length 12
# Dataframe has Block 2010 for new geovar BlockGroup2010
# Confirming BlockGroup2010 has expected length.
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Checking primary key name uniqueid_part1
# Primary key variable uniqueid_part1 is unique.
# Primary key uniqueid_part1 has no missing values
# ['uniqueid_part1', 'BlockGroup2010', 'Block2010', 'race', 'sex', 'hispan', 'agegroupLODES', 'earngingsgroupLODES1', 'earngingsgroupLODES2', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Initializing geovar flag set variable for jobid at geolevel BlockGroup2010
# New flag: jobid_BlockGroup2010_flagsetrm
# Observations without primary flag set 3398
# Observations without geovar flag set 6062
# After updated observations without geovar flag set 3398
# Setting 3398 flags for jobid secondary data not used.
# 0 observations do not have required variable BlockGroup2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable BlockGroup2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 3398 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['uniqueid_part1']
# Sorting before random merge order by ['BlockGroup2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['BlockGroup2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['BlockGroup2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder']
# Primary data frame has extra jobid  observations with no match: 120757
# Observations with no match filled with -999
# Merge found extra jobid  observations: 621
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'BlockGroup2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder', 'uniqueid_part1', 'jobid', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance', 'check_merge', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm']
# Observations without primary flag set 124155
# Observations without geovar flag set 124155
# After updated observations without geovar flag set 124155
# Round = 2
# Setting 2777 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable BlockGroup2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable BlockGroup2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Observations geovar flag set 2 = 2777
# After Recombime flag set 2 = 2777
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm']
# Before update output_df observations flag set 2 = 0
# Before update results observations flag set 2 = 2777
# After update observations geovar flag set 2 = 2777
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag jobid_BlockGroup2010_flagsetrm
# Observations flag not equal to 0 13411
# Input and output data have the same length 134168
# Outputdata has 13411 Observations with predicted jobid
# Percent left to predict: 90.00
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm']
# Before update output_df observations flag set 2 = 0
# Before update results observations flag set 2 = 2777
# After update observations geovar flag set 2 = 2777
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag jobid_BlockGroup2010_flagsetrm
# Observations flag not equal to 0 5441
# Input and output data have the same length 6062
# Outputdata has 5441 Observations with predicted jobid
# Percent left to predict: 10.24
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  90.004323
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Tract
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge householder                         on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Tract2010', 'BlockGroup2010', 'Block2010']
# Adding Tract2010 expected length 11
# Dataframe has Block 2010 for new geovar Tract2010
# Confirming Tract2010 has expected length.
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'Tract2010', 'BlockGroup2010', 'Block2010', 'huid', 'pernum', 'Block2010str', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'agegroupLODES', 'PossibleWorker', 'EstTotalWorkers1', 'EstTotalWorkers2', 'EstTotalWorkers3', 'randincome', 'randAnnualEarnings1', 'randMonthEarnings1', 'earngingsgroupLODES1', 'randAnnualEarnings2', 'randMonthEarnings2', 'earngingsgroupLODES2', 'randAnnualEarnings3', 'randMonthEarnings3', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Initializing geovar flag set variable for jobid at geolevel Tract2010
# New flag: jobid_Tract2010_flagsetrm
# Observations without primary flag set 128727
# Observations without geovar flag set 134168
# After updated observations without geovar flag set 128727
# Setting 0 flags for jobid set before random merge.
# 0 observations do not have required variable Tract2010
# 7970 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable Tract2010
# Setting 7970 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 120757 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['BlockGroup2010', 'Block2010']
# Adding Tract2010 expected length 11
# Dataframe has Block 2010 for new geovar Tract2010
# Confirming Tract2010 has expected length.
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Checking primary key name uniqueid_part1
# Primary key variable uniqueid_part1 is unique.
# Primary key uniqueid_part1 has no missing values
# ['uniqueid_part1', 'Tract2010', 'BlockGroup2010', 'Block2010', 'race', 'sex', 'hispan', 'agegroupLODES', 'earngingsgroupLODES1', 'earngingsgroupLODES2', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Initializing geovar flag set variable for jobid at geolevel Tract2010
# New flag: jobid_Tract2010_flagsetrm
# Observations without primary flag set 621
# Observations without geovar flag set 6062
# After updated observations without geovar flag set 621
# Setting 621 flags for jobid secondary data not used.
# 0 observations do not have required variable Tract2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable Tract2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 621 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['uniqueid_part1']
# Sorting before random merge order by ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder']
# Primary data frame has extra jobid  observations with no match: 120545
# Observations with no match filled with -999
# Merge found extra jobid  observations: 409
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder', 'uniqueid_part1', 'jobid', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance', 'check_merge', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm']
# Observations without primary flag set 121166
# Observations without geovar flag set 121166
# After updated observations without geovar flag set 121166
# Round = 3
# Setting 212 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Tract2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable Tract2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Observations geovar flag set 3 = 212
# After Recombime flag set 3 = 212
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm']
# Before update output_df observations flag set 3 = 0
# Before update results observations flag set 3 = 212
# After update observations geovar flag set 3 = 212
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag jobid_Tract2010_flagsetrm
# Observations flag not equal to 0 13623
# Input and output data have the same length 134168
# Outputdata has 13623 Observations with predicted jobid
# Percent left to predict: 89.85
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm']
# Before update output_df observations flag set 3 = 0
# Before update results observations flag set 3 = 212
# After update observations geovar flag set 3 = 212
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag jobid_Tract2010_flagsetrm
# Observations flag not equal to 0 5653
# Input and output data have the same length 6062
# Outputdata has 5653 Observations with predicted jobid
# Percent left to predict:  6.75
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  89.846312
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: County
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge householder                         on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Tract2010', 'BlockGroup2010', 'Block2010']
# Adding County2010 expected length 5
# Dataframe has Block 2010 for new geovar County2010
# Confirming County2010 has expected length.
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'County2010', 'Tract2010', 'BlockGroup2010', 'Block2010', 'huid', 'pernum', 'Block2010str', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'agegroupLODES', 'PossibleWorker', 'EstTotalWorkers1', 'EstTotalWorkers2', 'EstTotalWorkers3', 'randincome', 'randAnnualEarnings1', 'randMonthEarnings1', 'earngingsgroupLODES1', 'randAnnualEarnings2', 'randMonthEarnings2', 'earngingsgroupLODES2', 'randAnnualEarnings3', 'randMonthEarnings3', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Initializing geovar flag set variable for jobid at geolevel County2010
# New flag: jobid_County2010_flagsetrm
# Observations without primary flag set 128515
# Observations without geovar flag set 134168
# After updated observations without geovar flag set 128515
# Setting 0 flags for jobid set before random merge.
# 0 observations do not have required variable County2010
# 7970 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable County2010
# Setting 7970 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 120545 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Tract2010', 'BlockGroup2010', 'Block2010']
# Adding County2010 expected length 5
# Dataframe has Block 2010 for new geovar County2010
# Confirming County2010 has expected length.
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Checking primary key name uniqueid_part1
# Primary key variable uniqueid_part1 is unique.
# Primary key uniqueid_part1 has no missing values
# ['uniqueid_part1', 'County2010', 'Tract2010', 'BlockGroup2010', 'Block2010', 'race', 'sex', 'hispan', 'agegroupLODES', 'earngingsgroupLODES1', 'earngingsgroupLODES2', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Initializing geovar flag set variable for jobid at geolevel County2010
# New flag: jobid_County2010_flagsetrm
# Observations without primary flag set 409
# Observations without geovar flag set 6062
# After updated observations without geovar flag set 409
# Setting 409 flags for jobid secondary data not used.
# 0 observations do not have required variable County2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable County2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Attempting random merge for 409 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['uniqueid_part1']
# Sorting before random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_order']
# Generating random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder']
# Primary data frame has extra jobid  observations with no match: 120363
# Observations with no match filled with -999
# Merge found extra jobid  observations: 227
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES1', 'random_mergeorder', 'uniqueid_part1', 'jobid', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance', 'check_merge', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Observations without primary flag set 120772
# Observations without geovar flag set 120772
# After updated observations without geovar flag set 120772
# Round = 4
# Setting 182 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable County2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES1
# Setting 0 flags for observations without required variable County2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES1
# Observations geovar flag set 4 = 182
# After Recombime flag set 4 = 182
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Before update output_df observations flag set 4 = 0
# Before update results observations flag set 4 = 182
# After update observations geovar flag set 4 = 182
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag jobid_County2010_flagsetrm
# Observations flag not equal to 0 13805
# Input and output data have the same length 134168
# Outputdata has 13805 Observations with predicted jobid
# Percent left to predict: 89.71
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Before update output_df observations flag set 4 = 0
# Before update results observations flag set 4 = 182
# After update observations geovar flag set 4 = 182
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag jobid_County2010_flagsetrm
# Observations flag not equal to 0 5835
# Input and output data have the same length 6062
# Outputdata has 5835 Observations with predicted jobid
# Percent left to predict:  3.74
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  89.710661
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge householder                         on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES2']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['County2010', 'Tract2010', 'BlockGroup2010', 'Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'Block2010', 'County2010', 'Tract2010', 'BlockGroup2010', 'huid', 'pernum', 'Block2010str', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'agegroupLODES', 'PossibleWorker', 'EstTotalWorkers1', 'EstTotalWorkers2', 'EstTotalWorkers3', 'randincome', 'randAnnualEarnings1', 'randMonthEarnings1', 'earngingsgroupLODES1', 'randAnnualEarnings2', 'randMonthEarnings2', 'earngingsgroupLODES2', 'randAnnualEarnings3', 'randMonthEarnings3', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Observations without primary flag set 128333
# Observations without geovar flag set 123534
# After updated observations without geovar flag set 120363
# Setting 0 flags for jobid set before random merge.
# 0 observations do not have required variable Block2010
# 7970 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES2
# Attempting random merge for 120363 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES2', 'random_order']
# Generating random merge order by ['Block2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES2']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['County2010', 'Tract2010', 'BlockGroup2010', 'Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name uniqueid_part1
# Primary key variable uniqueid_part1 is unique.
# Primary key uniqueid_part1 has no missing values
# ['uniqueid_part1', 'Block2010', 'County2010', 'Tract2010', 'BlockGroup2010', 'race', 'sex', 'hispan', 'agegroupLODES', 'earngingsgroupLODES1', 'earngingsgroupLODES2', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Observations without primary flag set 227
# Observations without geovar flag set 3398
# After updated observations without geovar flag set 227
# Setting 227 flags for jobid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable agegroupLODES
# ...
# 0 observations do not have required variable Tract2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES3
# Setting 0 flags for observations without required variable Tract2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES3
# Attempting random merge for 182 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['uniqueid_part1']
# Sorting before random merge order by ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3', 'random_order']
# Generating random merge order by ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3', 'random_mergeorder']
# Primary data frame has extra jobid  observations with no match: 120318
# Observations with no match filled with -999
# Merge found extra jobid  observations: 182
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'Tract2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3', 'random_mergeorder', 'uniqueid_part1', 'jobid', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance', 'check_merge', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Observations without primary flag set 120500
# Observations without geovar flag set 120500
# After updated observations without geovar flag set 120500
# Round = 3
# Setting 0 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Tract2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES3
# Setting 0 flags for observations without required variable Tract2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES3
# Observations geovar flag set 3 = 0
# After Recombime flag set 3 = 0
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Before update output_df observations flag set 3 = 217
# Before update results observations flag set 3 = 0
# After update observations geovar flag set 3 = 217
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag jobid_Tract2010_flagsetrm
# Observations flag not equal to 0 13850
# Input and output data have the same length 134168
# Outputdata has 13850 Observations with predicted jobid
# Percent left to predict: 89.68
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Before update output_df observations flag set 3 = 217
# Before update results observations flag set 3 = 0
# After update observations geovar flag set 3 = 217
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag jobid_Tract2010_flagsetrm
# Observations flag not equal to 0 5880
# Input and output data have the same length 6062
# Outputdata has 5880 Observations with predicted jobid
# Percent left to predict:  3.00
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  89.677121
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: County
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge householder                         on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022133
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['County2010', 'Tract2010', 'BlockGroup2010', 'Block2010']
# Adding County2010 expected length 5
# Dataframe has Block 2010 for new geovar County2010
# Confirming County2010 has expected length.
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Checking primary key name precid
# Primary key variable precid is unique.
# Primary key precid has no missing values
# ['precid', 'County2010', 'Tract2010', 'BlockGroup2010', 'Block2010', 'huid', 'pernum', 'Block2010str', 'sex', 'race', 'hispan', 'randageP12', 'agegroupP12', 'randagePCT12', 'agegroupP43', 'agegroupH18', 'agegroupH17', 'child', 'gqtype', 'numprec', 'family', 'agegroupLODES', 'PossibleWorker', 'EstTotalWorkers1', 'EstTotalWorkers2', 'EstTotalWorkers3', 'randincome', 'randAnnualEarnings1', 'randMonthEarnings1', 'earngingsgroupLODES1', 'randAnnualEarnings2', 'randMonthEarnings2', 'earngingsgroupLODES2', 'randAnnualEarnings3', 'randMonthEarnings3', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Observations without primary flag set 128288
# Observations without geovar flag set 120320
# After updated observations without geovar flag set 120318
# Setting 0 flags for jobid set before random merge.
# 0 observations do not have required variable County2010
# 7970 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES3
# Setting 0 flags for observations without required variable County2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES3
# Attempting random merge for 120318 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['precid']
# Sorting before random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3', 'random_order']
# Generating random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Longest Tract2010 : 37155962002
# Tract2010 Expected Length 11 Available Length 11
# Longest BlockGroup2010 : 371559620022
# BlockGroup2010 Expected Length 12 Available Length 12
# Longest Block2010 : 371559620022120
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['County2010', 'Tract2010', 'BlockGroup2010', 'Block2010']
# Adding County2010 expected length 5
# Dataframe has Block 2010 for new geovar County2010
# Confirming County2010 has expected length.
# Longest County2010 : 37155
# County2010 Expected Length 5 Available Length 5
# Checking primary key name uniqueid_part1
# Primary key variable uniqueid_part1 is unique.
# Primary key uniqueid_part1 has no missing values
# ['uniqueid_part1', 'County2010', 'Tract2010', 'BlockGroup2010', 'Block2010', 'race', 'sex', 'hispan', 'agegroupLODES', 'earngingsgroupLODES1', 'earngingsgroupLODES2', 'earngingsgroupLODES3', 'jobid', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance']
# Observations without primary flag set 182
# Observations without geovar flag set 184
# After updated observations without geovar flag set 182
# Setting 182 flags for jobid secondary data not used.
# 0 observations do not have required variable County2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES3
# Setting 0 flags for observations without required variable County2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES3
# Attempting random merge for 182 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['uniqueid_part1']
# Sorting before random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3', 'random_order']
# Generating random merge order by ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3', 'random_mergeorder']
# Primary data frame has extra jobid  observations with no match: 120307
# Observations with no match filled with -999
# Merge found extra jobid  observations: 171
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['precid', 'County2010', 'agegroupLODES', 'sex', 'race', 'hispan', 'earngingsgroupLODES3', 'random_mergeorder', 'uniqueid_part1', 'jobid', 'w_geometry', 'wcb_lat', 'wcb_lon', 'IndustryCode', 'jobtype', 'Earnings', 'Education', 'h_stabbr', 'od_distance', 'check_merge', 'jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Observations without primary flag set 120489
# Observations without geovar flag set 120489
# After updated observations without geovar flag set 120489
# Round = 4
# Setting 11 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable County2010
# 0 observations do not have required variable agegroupLODES
# 0 observations do not have required variable sex
# 0 observations do not have required variable race
# 0 observations do not have required variable hispan
# 0 observations do not have required variable earngingsgroupLODES3
# Setting 0 flags for observations without required variable County2010
# Setting 0 flags for observations without required variable agegroupLODES
# Setting 0 flags for observations without required variable sex
# Setting 0 flags for observations without required variable race
# Setting 0 flags for observations without required variable hispan
# Setting 0 flags for observations without required variable earngingsgroupLODES3
# Observations geovar flag set 4 = 11
# After Recombime flag set 4 = 11
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Before update output_df observations flag set 4 = 213
# Before update results observations flag set 4 = 11
# After update observations geovar flag set 4 = 224
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag jobid_County2010_flagsetrm
# Observations flag not equal to 0 13861
# Input and output data have the same length 134168
# Outputdata has 13861 Observations with predicted jobid
# Percent left to predict: 89.67
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['jobid_flagsetrm', 'jobid_Block2010_flagsetrm', 'jobid_BlockGroup2010_flagsetrm', 'jobid_Tract2010_flagsetrm', 'jobid_County2010_flagsetrm']
# Before update output_df observations flag set 4 = 213
# Before update results observations flag set 4 = 11
# After update observations geovar flag set 4 = 224
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag jobid_County2010_flagsetrm
# Observations flag not equal to 0 5891
# Input and output data have the same length 6062
# Outputdata has 5891 Observations with predicted jobid
# Percent left to predict:  2.82
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  89.668923
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
#
# ***************************************
#     Append jobs for workers that live outside county.
# ***************************************
#
# The person record file has 134168 records.
# With workers outside county, the person record file has 135962 records.

# %%
prechui_lodes_df.head()
# Out:
#                   precid County2010    Tract2010 BlockGroup2010  \
# 0  B371559601011002P0002      37155  37155960101   371559601011
# 1  B371559601011002P0001      37155  37155960101   371559601011
# 2  B371559601011003P0002      37155  37155960101   371559601011
# 3  B371559601011003P0003      37155  37155960101   371559601011
# 4  B371559601011003P0001      37155  37155960101   371559601011
#
#          Block2010                  huid  pernum      Block2010str  sex  race  \
# 0  371559601011002  B371559601011002H001     1.0  B371559601011002    1   2.0
# 1  371559601011002  B371559601011002H001     2.0  B371559601011002    2   1.0
# 2  371559601011003  B371559601011003H001     1.0  B371559601011003    1   1.0
# 3  371559601011003  B371559601011003H002     1.0  B371559601011003    2   1.0
# 4  371559601011003  B371559601011003H002     2.0  B371559601011003    1   1.0
#
#    ...  IndustryCode  jobtype  Earnings  Education  h_stabbr  od_distance  \
# 0  ...           NaN      NaN       NaN        NaN       NaN          NaN
# 1  ...           NaN      NaN       NaN        NaN       NaN          NaN
# 2  ...           NaN      NaN       NaN        NaN       NaN          NaN
# 3  ...          15.0     JT07       3.0        2.0        nc    30.027827
# 4  ...           NaN      NaN       NaN        NaN       NaN          NaN
#
#    w_geocode_str  h_geometry  hcb_lat  hcb_lon
# 0            NaN         NaN      NaN      NaN
# 1            NaN         NaN      NaN      NaN
# 2            NaN         NaN      NaN      NaN
# 3            NaN         NaN      NaN      NaN
# 4            NaN         NaN      NaN      NaN
#
# [5 rows x 55 columns]

# %%
viz.pop_results_table(prechui_lodes_df,
                who = "Total Jobs for persons working in county", 
                what = "by Job Type and NAICS Code",
                where = "Robeson County, NC",
                when = "2010",
                row_index = 'NAICS Industry Sector',
                col_index = 'Job Type')
# Out:
# ['Public Sector Primary Jobs', 'Total Jobs for persons working in county']
# <style type="text/css">
# #T_718e6 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_718e6">
#   <caption>Table. Total Jobs for persons working in county by Job Type and NAICS Code, Robeson County, NC, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Job Type</th>
#       <th id="T_718e6_level0_col0" class="col_heading level0 col0" >Public Sector Primary Jobs (%)</th>
#       <th id="T_718e6_level0_col1" class="col_heading level0 col1" >Total Jobs for persons working in county (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >NAICS Industry Sector</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_718e6_level0_row0" class="row_heading level0 row0" >44-45 Retail Trade</th>
#       <td id="T_718e6_row0_col0" class="data row0 col0" >44	 (0.6%)</td>
#       <td id="T_718e6_row0_col1" class="data row0 col1" >44	 (0.6%)</td>
#     </tr>
#     <tr>
#       <th id="T_718e6_level0_row1" class="row_heading level0 row1" >48-49 Transportation and Warehousing</th>
#       <td id="T_718e6_row1_col0" class="data row1 col0" >4	 (0.1%)</td>
#       <td id="T_718e6_row1_col1" class="data row1 col1" >4	 (0.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_718e6_level0_row2" class="row_heading level0 row2" >51 Information</th>
#       <td id="T_718e6_row2_col0" class="data row2 col0" >24	 (0.3%)</td>
#       <td id="T_718e6_row2_col1" class="data row2 col1" >24	 (0.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_718e6_level0_row3" class="row_heading level0 row3" >56 Administration & Support, Waste Management and Remediation</th>
#       <td id="T_718e6_row3_col0" class="data row3 col0" >1	 (0.0%)</td>
#       <td id="T_718e6_row3_col1" class="data row3 col1" >1	 (0.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_718e6_level0_row4" class="row_heading level0 row4" >61 Educational Services</th>
#       <td id="T_718e6_row4_col0" class="data row4 col0" >5,415	 (70.5%)</td>
#       <td id="T_718e6_row4_col1" class="data row4 col1" >5,415	 (70.5%)</td>
#     </tr>
#     <tr>
#       <th id="T_718e6_level0_row5" class="row_heading level0 row5" >62 Health Care and Social Assistance</th>
#       <td id="T_718e6_row5_col0" class="data row5 col0" >98	 (1.3%)</td>
#       <td id="T_718e6_row5_col1" class="data row5 col1" >98	 (1.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_718e6_level0_row6" class="row_heading level0 row6" >92 Public Administration</th>
#       <td id="T_718e6_row6_col0" class="data row6 col0" >2,099	 (27.3%)</td>
#       <td id="T_718e6_row6_col1" class="data row6 col1" >2,099	 (27.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_718e6_level0_row7" class="row_heading level0 row7" >Total</th>
#       <td id="T_718e6_row7_col0" class="data row7 col0" >7,685	 (100.0%)</td>
#       <td id="T_718e6_row7_col1" class="data row7 col1" >7,685	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Merge Establishment location with LODES data

# %%
estab_keep_vars = ['jobid','estabid','Longitude','Latitude','NAICS2D','NAICS4D','SIName']
prechui_lodes_estab_df = pd.merge(
        left = prechui_lodes_df,
        right = jrec_estab_df['primary'][estab_keep_vars],
        on = 'jobid',
        how = 'left'
)
lodes_keep_vars = ['agegroupLODES','Earnings','Education',
        'jobtype','IndustryCode', 'Block2010str',
        'w_geocode_str','h_stabbr','od_distance','w_geometry','h_geometry',
        'hcb_lat','hcb_lon','wcb_lat','wcb_lon','race','sex','hispan']
keep_vars =  ['precid'] + estab_keep_vars + lodes_keep_vars
prechui_lodes_estab_df_keep_vars = prechui_lodes_estab_df[keep_vars]

# %%
prechui_lodes_estab_df_keep_vars.head(1).T
# Out:
#                                    0
# precid         B371559601011002P0002
# jobid                           -999
# estabid                          NaN
# Longitude                        NaN
# Latitude                         NaN
# NAICS2D                          NaN
# NAICS4D                          NaN
# SIName                           NaN
# agegroupLODES                    3.0
# Earnings                         NaN
# Education                        NaN
# jobtype                          NaN
# IndustryCode                     NaN
# Block2010str        B371559601011002
# w_geocode_str                    NaN
# h_stabbr                         NaN
# od_distance                      NaN
# w_geometry                       NaN
# h_geometry                       NaN
# hcb_lat                          NaN
# hcb_lon                          NaN
# wcb_lat                          NaN
# wcb_lon                          NaN
# race                             2.0
# sex                                1
# hispan                           0.0

# %%
# Merge LODES Establishments with Student Record Data
# Merge on person id, race, sex, and hispan to keep values for new persons in joblist
# Job list adds people who live outside of Robeson County
prechui_srec_lodes_estab_df = pd.merge(
        left = prechui_srec_df['primary'],
        right = prechui_lodes_estab_df_keep_vars,
        on = ['precid','race','sex','hispan'],
        how = 'outer'
)

prechui_srec_lodes_estab_df.head(1).T
# Out:
#                                     0
# precid          B371559601011002P0002
# huid             B371559601011002H001
# pernum                            1.0
# Block2010str_x       B371559601011002
# Block2010             371559601011002
# ...                               ...
# h_geometry                        NaN
# hcb_lat_y                         NaN
# hcb_lon_y                         NaN
# wcb_lat                           NaN
# wcb_lon                           NaN
#
# [78 rows x 1 columns]

# %%
list(prechui_srec_lodes_estab_df.columns)
# Out:
# ['precid',
#  'huid',
#  'pernum',
#  'Block2010str_x',
#  'Block2010',
#  'Tract2010',
#  'sex',
#  'race',
#  'hispan',
#  'randageP12',
#  'agegroupP12',
#  'randagePCT12',
#  'agegroupP43',
#  'agegroupH18',
#  'agegroupH17',
#  'child',
#  'gqtype',
#  'numprec',
#  'family',
#  'PLCGEOID10',
#  'PLCNAME10',
#  'PUMGEOID10',
#  'rppnt4269',
#  'gradelevel1',
#  'gradelevel2',
#  'gradelevel3',
#  'racecat5',
#  'BLOCKID10',
#  'ncessch_3',
#  'high_schnm',
#  'ncessch_2',
#  'mid_schnm',
#  'ncessch_1',
#  'primary_schnm',
#  'ncessch_5',
#  'overalsab_schnm',
#  'ncessch_6',
#  'charter_schnm',
#  'CommunityFocus',
#  'NCESSCH',
#  'NCESSCH_flagsetrm',
#  'NCESSCH_ncessch_1_flagsetrm',
#  'NCESSCH_ncessch_2_flagsetrm',
#  'NCESSCH_ncessch_3_flagsetrm',
#  'NCESSCH_ncessch_5_flagsetrm',
#  'NCESSCH_ncessch_6_flagsetrm',
#  'SCHNAM09',
#  'gradelevel',
#  'LATCOD09',
#  'LONCOD09',
#  'geometry',
#  'geocode_type',
#  'hcb_lon_x',
#  'hcb_lat_x',
#  'Race Ethnicity',
#  'Family Type',
#  'jobid',
#  'estabid',
#  'Longitude',
#  'Latitude',
#  'NAICS2D',
#  'NAICS4D',
#  'SIName',
#  'agegroupLODES',
#  'Earnings',
#  'Education',
#  'jobtype',
#  'IndustryCode',
#  'Block2010str_y',
#  'w_geocode_str',
#  'h_stabbr',
#  'od_distance',
#  'w_geometry',
#  'h_geometry',
#  'hcb_lat_y',
#  'hcb_lon_y',
#  'wcb_lat',
#  'wcb_lon']

# %% [markdown]
# ## Keep Primary Columns Merge

# %%
def update_cols_after_merge(input_df,column_name):
    """
    After merge need to update the columns that will be repeated
    """
    if column_name+'_y' in list(input_df.columns):
        input_df[column_name] = \
            input_df[column_name+'_y'].fillna(input_df[column_name+'_x'])
        # Drop duplicate columns
        input_df = input_df.drop([column_name+'_x', column_name+'_y'], axis=1)

    return input_df

prechui_srec_lodes_estab_df = update_cols_after_merge(prechui_srec_lodes_estab_df,
                                column_name = 'Block2010str')
                                
prechui_srec_lodes_estab_df = update_cols_after_merge(prechui_srec_lodes_estab_df,
                                column_name = 'hcb_lat')
prechui_srec_lodes_estab_df = update_cols_after_merge(prechui_srec_lodes_estab_df,
                                column_name = 'hcb_lon')

# %%
person_recordid_keep_vars =  ['precid','huid','pernum','Block2010str']
person_record_char_keep_vars = ['sex','race','hispan','randagePCT12',
                    'child', 'gqtype', 'numprec', 'family']
student_record_char_keep_vars = ['gradelevel']
student_record_id_keep_vars = ['NCESSCH','SCHNAM09','LATCOD09','LONCOD09']
geo_keep_vars = ['PLCGEOID10','PLCNAME10','CommunityFocus',
                 'PUMGEOID10','rppnt4269']
estab_geo_keep_vars = ['Longitude','Latitude']
job_char_keep_vars = ['agegroupLODES','Earnings','Education',
                        'jobtype','IndustryCode',
                        'NAICS2D','NAICS4D','estabid','SIName']
lodes_geo_keep_vars =  ['h_stabbr','od_distance','h_geometry',
                        'hcb_lat','hcb_lon','wcb_lat','wcb_lon','od_distance']
keep_vars = person_recordid_keep_vars + geo_keep_vars + \
    person_record_char_keep_vars + \
    student_record_char_keep_vars + job_char_keep_vars + \
    student_record_id_keep_vars + \
    estab_geo_keep_vars + lodes_geo_keep_vars

# %%
icd_df = prechui_srec_lodes_estab_df[keep_vars]
icd_df.head(1).T
# Out:
#                                                     0
# precid                          B371559601011002P0002
# huid                             B371559601011002H001
# pernum                                            1.0
# Block2010str                         B371559601011002
# PLCGEOID10                                        NaN
# PLCNAME10                              Unincorporated
# CommunityFocus                      Outside Community
# PUMGEOID10                                  3705100.0
# rppnt4269       POINT (-78.94751707644164 34.9055645)
# sex                                                 1
# race                                              2.0
# hispan                                            0.0
# randagePCT12                                     64.0
# child                                             0.0
# gqtype                                            0.0
# numprec                                           2.0
# family                                            1.0
# gradelevel                                        NaN
# agegroupLODES                                     3.0
# Earnings                                          NaN
# Education                                         NaN
# jobtype                                           NaN
# IndustryCode                                      NaN
# NAICS2D                                           NaN
# NAICS4D                                           NaN
# estabid                                           NaN
# SIName                                            NaN
# NCESSCH                                           NaN
# SCHNAM09                                          NaN
# LATCOD09                                          NaN
# LONCOD09                                          NaN
# Longitude                                         NaN
# Latitude                                          NaN
# h_stabbr                                          NaN
# od_distance                                       NaN
# h_geometry                                        NaN
# hcb_lat                                     34.905562
# hcb_lon                                    -78.947516
# wcb_lat                                           NaN
# wcb_lon                                           NaN
# od_distance                                       NaN

# %% [markdown]
# ## Rename Geography Columns

# %%
icd_df = icd_df.rename(columns={'Longitude':'wet_lon',
                                'Latitude' :'wet_lat',
                                'LONCOD09' :'ncs_lon',
                                'LATCOD09' :'ncs_lat'})

# %%
icd_df.head(1).T
# Out:
#                                                     0
# precid                          B371559601011002P0002
# huid                             B371559601011002H001
# pernum                                            1.0
# Block2010str                         B371559601011002
# PLCGEOID10                                        NaN
# PLCNAME10                              Unincorporated
# CommunityFocus                      Outside Community
# PUMGEOID10                                  3705100.0
# rppnt4269       POINT (-78.94751707644164 34.9055645)
# sex                                                 1
# race                                              2.0
# hispan                                            0.0
# randagePCT12                                     64.0
# child                                             0.0
# gqtype                                            0.0
# numprec                                           2.0
# family                                            1.0
# gradelevel                                        NaN
# agegroupLODES                                     3.0
# Earnings                                          NaN
# Education                                         NaN
# jobtype                                           NaN
# IndustryCode                                      NaN
# NAICS2D                                           NaN
# NAICS4D                                           NaN
# estabid                                           NaN
# SIName                                            NaN
# NCESSCH                                           NaN
# SCHNAM09                                          NaN
# ncs_lat                                           NaN
# ncs_lon                                           NaN
# wet_lon                                           NaN
# wet_lat                                           NaN
# h_stabbr                                          NaN
# od_distance                                       NaN
# h_geometry                                        NaN
# hcb_lat                                     34.905562
# hcb_lon                                    -78.947516
# wcb_lat                                           NaN
# wcb_lon                                           NaN
# od_distance                                       NaN

# %% [markdown]
# ## Add line strings for Origin and Destinations

# %%
icd_df = wkt_line(icd_df, x1='hcb_lon', y1='hcb_lat', x2='ncs_lon', y2='ncs_lat',
                    linestring_var = 'hcb_ncs_line')
icd_df = wkt_line(icd_df, x1='hcb_lon', y1='hcb_lat', x2='wet_lon', y2='wet_lat',
                    linestring_var = 'hcb_wet_line')
# Out:
# Number of rows in selected dataframe:  23122
# Number of rows in not selected dataframe:  112840
# return pandas dataframe with WKT Linestring.
# Linestring can be converted to geometry variable.
# Number of rows in selected dataframe:  7685
# Number of rows in not selected dataframe:  128277
# return pandas dataframe with WKT Linestring.
# Linestring can be converted to geometry variable.

# %%
icd_df.head(1).T
# Out:
#                                                             12050
# precid                                      B371559602012079P0063
# huid                                         B371559602012079H033
# pernum                                                        5.0
# Block2010str                                     B371559602012079
# PLCGEOID10                                                    NaN
# PLCNAME10                                          Unincorporated
# CommunityFocus                                  Outside Community
# PUMGEOID10                                              3705100.0
# rppnt4269                   POINT (-79.07091010522959 34.8609445)
# sex                                                             2
# race                                                          3.0
# hispan                                                        0.0
# randagePCT12                                                 18.0
# child                                                         0.0
# gqtype                                                        0.0
# numprec                                                       7.0
# family                                                        1.0
# gradelevel                                                    G12
# agegroupLODES                                                 1.0
# Earnings                                                      1.0
# Education                                                     0.0
# jobtype                                                      JT07
# IndustryCode                                                 15.0
# NAICS2D                                                      61.0
# NAICS4D                                                    6113.0
# estabid                                             E37155N61C009
# SIName                                  ROBESON COMMUNITY COLLEGE
# NCESSCH                                              370393002244
# SCHNAM09                                         SAINT PAULS HIGH
# ncs_lat                                                   34.8126
# ncs_lon                                                 -78.97637
# wet_lon                                                -79.006439
# wet_lat                                                 34.677103
# h_stabbr                                                       nc
# od_distance                                             27.790132
# h_geometry                                                    NaN
# hcb_lat                                                 34.860941
# hcb_lon                                                -79.070909
# wcb_lat                                                  34.62121
# wcb_lon                                                -79.006843
# od_distance                                             27.790132
# hcb_ncs_line    LINESTRING ( -79.07090930164958 34.86094119058...
# hcb_wet_line    LINESTRING ( -79.07090930164958 34.86094119058...

# %%
from pyincore_data_addons.ICD00b_directory_design import directory_design

# Setup directory design
for community in communities.keys():
    print("Intersect Community Data for:",\
        communities[community]['community_name'])
    for county in communities[community]['counties'].keys():
        state_county = communities[community]['counties'][county]['FIPS Code']
        state_county_name  = communities[community]['counties'][county]['Name']
        print(state_county_name,': county FIPS Code',state_county)
    
        outputfolders = directory_design(state_county_name = state_county_name,
                                            outputfolder = outputfolder)
# Out:
# Intersect Community Data for: Lumberton, NC
# Robeson County, NC : county FIPS Code 37155

# %%
output_filename = f'prec_{version_text}_{community}_{basevintage}_rs{seed}'
output_filepath = os.path.join(outputfolders['top'], output_filename)
print('Saving to:',output_filepath)
icd_df.to_csv(output_filepath+'.csv', index=False)
# Out:
# Saving to: ICD_workflow_2022-01-19/RobesonCounty_NC\prec_v0-2-0_Lumberton_NC_2010_rs9876

# %% [markdown]
# ## Explore results

# %%
viz.pop_results_table(icd_df,
                who = "Total Population by Persons", 
                what = "by Gradelevel",
                where = "Robeson County, NC",
                when = "2010",
                row_index = 'gradelevel',
                col_index = 'CommunityFocus')
# Out:
# ['Inside Community', 'Outside Community', 'Total Population by Persons']
# <style type="text/css">
# #T_01b75 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_01b75">
#   <caption>Table. Total Population by Persons by Gradelevel, Robeson County, NC, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >CommunityFocus</th>
#       <th id="T_01b75_level0_col0" class="col_heading level0 col0" >Inside Community (%)</th>
#       <th id="T_01b75_level0_col1" class="col_heading level0 col1" >Outside Community (%)</th>
#       <th id="T_01b75_level0_col2" class="col_heading level0 col2" >Total Population by Persons (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gradelevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01b75_level0_row0" class="row_heading level0 row0" >G01</th>
#       <td id="T_01b75_row0_col0" class="data row0 col0" >274	 (7.3%)</td>
#       <td id="T_01b75_row0_col1" class="data row0 col1" >1,528	 (7.9%)</td>
#       <td id="T_01b75_row0_col2" class="data row0 col2" >1,802	 (7.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row1" class="row_heading level0 row1" >G02</th>
#       <td id="T_01b75_row1_col0" class="data row1 col0" >281	 (7.5%)</td>
#       <td id="T_01b75_row1_col1" class="data row1 col1" >1,485	 (7.7%)</td>
#       <td id="T_01b75_row1_col2" class="data row1 col2" >1,766	 (7.6%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row2" class="row_heading level0 row2" >G03</th>
#       <td id="T_01b75_row2_col0" class="data row2 col0" >307	 (8.2%)</td>
#       <td id="T_01b75_row2_col1" class="data row2 col1" >1,544	 (8.0%)</td>
#       <td id="T_01b75_row2_col2" class="data row2 col2" >1,851	 (8.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row3" class="row_heading level0 row3" >G04</th>
#       <td id="T_01b75_row3_col0" class="data row3 col0" >310	 (8.2%)</td>
#       <td id="T_01b75_row3_col1" class="data row3 col1" >1,627	 (8.4%)</td>
#       <td id="T_01b75_row3_col2" class="data row3 col2" >1,937	 (8.4%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row4" class="row_heading level0 row4" >G05</th>
#       <td id="T_01b75_row4_col0" class="data row4 col0" >301	 (8.0%)</td>
#       <td id="T_01b75_row4_col1" class="data row4 col1" >1,543	 (8.0%)</td>
#       <td id="T_01b75_row4_col2" class="data row4 col2" >1,844	 (8.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row5" class="row_heading level0 row5" >G06</th>
#       <td id="T_01b75_row5_col0" class="data row5 col0" >289	 (7.7%)</td>
#       <td id="T_01b75_row5_col1" class="data row5 col1" >1,543	 (8.0%)</td>
#       <td id="T_01b75_row5_col2" class="data row5 col2" >1,832	 (7.9%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row6" class="row_heading level0 row6" >G07</th>
#       <td id="T_01b75_row6_col0" class="data row6 col0" >311	 (8.3%)</td>
#       <td id="T_01b75_row6_col1" class="data row6 col1" >1,433	 (7.4%)</td>
#       <td id="T_01b75_row6_col2" class="data row6 col2" >1,744	 (7.5%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row7" class="row_heading level0 row7" >G08</th>
#       <td id="T_01b75_row7_col0" class="data row7 col0" >287	 (7.6%)</td>
#       <td id="T_01b75_row7_col1" class="data row7 col1" >1,351	 (7.0%)</td>
#       <td id="T_01b75_row7_col2" class="data row7 col2" >1,638	 (7.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row8" class="row_heading level0 row8" >G09</th>
#       <td id="T_01b75_row8_col0" class="data row8 col0" >294	 (7.8%)</td>
#       <td id="T_01b75_row8_col1" class="data row8 col1" >1,767	 (9.1%)</td>
#       <td id="T_01b75_row8_col2" class="data row8 col2" >2,061	 (8.9%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row9" class="row_heading level0 row9" >G10</th>
#       <td id="T_01b75_row9_col0" class="data row9 col0" >307	 (8.2%)</td>
#       <td id="T_01b75_row9_col1" class="data row9 col1" >1,496	 (7.7%)</td>
#       <td id="T_01b75_row9_col2" class="data row9 col2" >1,803	 (7.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row10" class="row_heading level0 row10" >G11</th>
#       <td id="T_01b75_row10_col0" class="data row10 col0" >253	 (6.7%)</td>
#       <td id="T_01b75_row10_col1" class="data row10 col1" >1,177	 (6.1%)</td>
#       <td id="T_01b75_row10_col2" class="data row10 col2" >1,430	 (6.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row11" class="row_heading level0 row11" >G12</th>
#       <td id="T_01b75_row11_col0" class="data row11 col0" >210	 (5.6%)</td>
#       <td id="T_01b75_row11_col1" class="data row11 col1" >1,072	 (5.5%)</td>
#       <td id="T_01b75_row11_col2" class="data row11 col2" >1,282	 (5.5%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row12" class="row_heading level0 row12" >KG</th>
#       <td id="T_01b75_row12_col0" class="data row12 col0" >279	 (7.4%)</td>
#       <td id="T_01b75_row12_col1" class="data row12 col1" >1,353	 (7.0%)</td>
#       <td id="T_01b75_row12_col2" class="data row12 col2" >1,632	 (7.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row13" class="row_heading level0 row13" >PK</th>
#       <td id="T_01b75_row13_col0" class="data row13 col0" >61	 (1.6%)</td>
#       <td id="T_01b75_row13_col1" class="data row13 col1" >439	 (2.3%)</td>
#       <td id="T_01b75_row13_col2" class="data row13 col2" >500	 (2.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_01b75_level0_row14" class="row_heading level0 row14" >Total</th>
#       <td id="T_01b75_row14_col0" class="data row14 col0" >3,764	 (100.0%)</td>
#       <td id="T_01b75_row14_col1" class="data row14 col1" >19,358	 (100.0%)</td>
#       <td id="T_01b75_row14_col2" class="data row14 col2" >23,122	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
icd_df["LiveLumbertonCity"] = "LiveOutsideRobesonCounty"
icd_df.loc[(icd_df['Block2010str'].str.startswith('B37155')),\
    "LiveLumbertonCity"] = "LiveOutsideLumbertonCity"
icd_df.loc[icd_df['PLCNAME10']=='Lumberton',"LiveLumbertonCity"] = "LiveInsideLumbertonCity"

# %%
viz.pop_results_table(icd_df,
                who = "Total Jobs", 
                what = "by Job Type and NAICS Code",
                where = "Robeson County, NC",
                when = "2010",
                row_index = 'NAICS Industry Sector',
                col_index = 'LiveLumbertonCity',
                row_percent = 'LiveInsideLumbertonCity')
# Out:
# ['LiveInsideLumbertonCity', 'LiveOutsideLumbertonCity', 'LiveOutsideRobesonCounty', 'Total Jobs']
# <style type="text/css">
# #T_fa642 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_fa642">
#   <caption>Table. Total Jobs by Job Type and NAICS Code, Robeson County, NC, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >LiveLumbertonCity</th>
#       <th id="T_fa642_level0_col0" class="col_heading level0 col0" >LiveInsideLumbertonCity (%)</th>
#       <th id="T_fa642_level0_col1" class="col_heading level0 col1" >LiveOutsideLumbertonCity (%)</th>
#       <th id="T_fa642_level0_col2" class="col_heading level0 col2" >LiveOutsideRobesonCounty (%)</th>
#       <th id="T_fa642_level0_col3" class="col_heading level0 col3" >Total Jobs (%)</th>
#       <th id="T_fa642_level0_col4" class="col_heading level0 col4" >Percent Row
# LiveInsideLumbertonCity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >NAICS Industry Sector</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa642_level0_row0" class="row_heading level0 row0" >44-45 Retail Trade</th>
#       <td id="T_fa642_row0_col0" class="data row0 col0" >7	 (0.6%)</td>
#       <td id="T_fa642_row0_col1" class="data row0 col1" >28	 (0.6%)</td>
#       <td id="T_fa642_row0_col2" class="data row0 col2" >9	 (0.5%)</td>
#       <td id="T_fa642_row0_col3" class="data row0 col3" >44	 (0.6%)</td>
#       <td id="T_fa642_row0_col4" class="data row0 col4" >15.9%</td>
#     </tr>
#     <tr>
#       <th id="T_fa642_level0_row1" class="row_heading level0 row1" >48-49 Transportation and Warehousing</th>
#       <td id="T_fa642_row1_col0" class="data row1 col0" >2	 (0.2%)</td>
#       <td id="T_fa642_row1_col1" class="data row1 col1" >2	 (0.0%)</td>
#       <td id="T_fa642_row1_col2" class="data row1 col2" >nan	 (nan%)</td>
#       <td id="T_fa642_row1_col3" class="data row1 col3" >4	 (0.1%)</td>
#       <td id="T_fa642_row1_col4" class="data row1 col4" >50.0%</td>
#     </tr>
#     <tr>
#       <th id="T_fa642_level0_row2" class="row_heading level0 row2" >51 Information</th>
#       <td id="T_fa642_row2_col0" class="data row2 col0" >7	 (0.6%)</td>
#       <td id="T_fa642_row2_col1" class="data row2 col1" >11	 (0.2%)</td>
#       <td id="T_fa642_row2_col2" class="data row2 col2" >6	 (0.3%)</td>
#       <td id="T_fa642_row2_col3" class="data row2 col3" >24	 (0.3%)</td>
#       <td id="T_fa642_row2_col4" class="data row2 col4" >29.2%</td>
#     </tr>
#     <tr>
#       <th id="T_fa642_level0_row3" class="row_heading level0 row3" >56 Administration & Support, Waste Management and Remediation</th>
#       <td id="T_fa642_row3_col0" class="data row3 col0" >nan	 (nan%)</td>
#       <td id="T_fa642_row3_col1" class="data row3 col1" >1	 (0.0%)</td>
#       <td id="T_fa642_row3_col2" class="data row3 col2" >nan	 (nan%)</td>
#       <td id="T_fa642_row3_col3" class="data row3 col3" >1	 (0.0%)</td>
#       <td id="T_fa642_row3_col4" class="data row3 col4" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_fa642_level0_row4" class="row_heading level0 row4" >61 Educational Services</th>
#       <td id="T_fa642_row4_col0" class="data row4 col0" >786	 (63.3%)</td>
#       <td id="T_fa642_row4_col1" class="data row4 col1" >3,216	 (69.2%)</td>
#       <td id="T_fa642_row4_col2" class="data row4 col2" >1,413	 (78.8%)</td>
#       <td id="T_fa642_row4_col3" class="data row4 col3" >5,415	 (70.5%)</td>
#       <td id="T_fa642_row4_col4" class="data row4 col4" >14.5%</td>
#     </tr>
#     <tr>
#       <th id="T_fa642_level0_row5" class="row_heading level0 row5" >62 Health Care and Social Assistance</th>
#       <td id="T_fa642_row5_col0" class="data row5 col0" >29	 (2.3%)</td>
#       <td id="T_fa642_row5_col1" class="data row5 col1" >28	 (0.6%)</td>
#       <td id="T_fa642_row5_col2" class="data row5 col2" >41	 (2.3%)</td>
#       <td id="T_fa642_row5_col3" class="data row5 col3" >98	 (1.3%)</td>
#       <td id="T_fa642_row5_col4" class="data row5 col4" >29.6%</td>
#     </tr>
#     <tr>
#       <th id="T_fa642_level0_row6" class="row_heading level0 row6" >92 Public Administration</th>
#       <td id="T_fa642_row6_col0" class="data row6 col0" >411	 (33.1%)</td>
#       <td id="T_fa642_row6_col1" class="data row6 col1" >1,363	 (29.3%)</td>
#       <td id="T_fa642_row6_col2" class="data row6 col2" >325	 (18.1%)</td>
#       <td id="T_fa642_row6_col3" class="data row6 col3" >2,099	 (27.3%)</td>
#       <td id="T_fa642_row6_col4" class="data row6 col4" >19.6%</td>
#     </tr>
#     <tr>
#       <th id="T_fa642_level0_row7" class="row_heading level0 row7" >Total</th>
#       <td id="T_fa642_row7_col0" class="data row7 col0" >1,242	 (100.0%)</td>
#       <td id="T_fa642_row7_col1" class="data row7 col1" >4,649	 (100.0%)</td>
#       <td id="T_fa642_row7_col2" class="data row7 col2" >1,794	 (100.0%)</td>
#       <td id="T_fa642_row7_col3" class="data row7 col3" >7,685	 (100.0%)</td>
#       <td id="T_fa642_row7_col4" class="data row7 col4" >16.2%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Add GUID with Address point Place
# To determine if the job is inside Lumberton need to look at the location of the building. This will not be the same as the numbers provided by CES OnTheMap. The difference is due to the bridge between the data-axel establishment locations and where LODES data is geocoded.

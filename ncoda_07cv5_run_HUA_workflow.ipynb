# %% [markdown]
# # Housing Unit Allocation Full Workflow
#
# ## Overview
# Given a building inventory that uses IN-CORE standard columns, run housing unit allocation.
# This process checks to see if the housing unit inventory is available and if not it will create it.
# This process checks to see if the address point inventory is available and if not it will create it.
#
# With the housing unit inventory and address point inventory created, they will be uploaded to IN-CORE Dataservice.
#
# With the required files on IN-CORE Dataservice, the housing unit allocation method will run.
# Functions are provided to obtain and clean data required for the version 2 Housing Unit Allocation.
#
# ## Required Inputs
# Program requires the following inputs:
# 1. Building inventory file from pyincore
#     - IN-CORE account
#
# ## Output Description
# The output of this workflow is a CSV file with the housing unit inventory allocated to a building inventory using the housing unit allocation model.
#
# The output CSV is designed to be used in the Interdependent Networked Community Resilience Modeling Environment (IN-CORE).
#
# IN-CORE is an open source python package that can be used to model the resilience of a community. To download IN-CORE, see:
#
# https://incore.ncsa.illinois.edu/
#
#
# ## Instructions
# Users can run the workflow by executing each block of code in the notebook.

# %% [markdown]
# ## Description of Program
# - program:    ncoda_07cv4_run_HUA_workflow
# - task:       Start with building inventory and run housing unit allocation algorithm
# - See github commits for description of program updates
# - Current Version: 2023-01-27 - Generalize workflow using new Lumberton Building Data
# - 2022-08-29 - v2 workflow
# - 2022-10-06 - clean up code and test output for Salt Lake City
# - project:    Interdependent Networked Community Resilience Modeling Environment (IN-CORE), Subtask 5.2 - Social Institutions
# - funding:	  NIST Financial Assistance Award Numbers: 70NANB15H044 and 70NANB20H008
# - author:     Nathanael Rosenheim
#
# - Suggested Citation:
# Rosenheim, Nathanael (2021) “Detailed Household and Housing Unit Characteristics: Data and Replication Code.” DesignSafe-CI.
# https://doi.org/10.17603/ds2-jwf6-s535.

# %% [markdown]
# ## Setup Python Environment

# %%
import pandas as pd
import geopandas as gpd # For reading in shapefiles
import numpy as np
import sys # For displaying package versions
import os # For managing directories and file paths if drive is mounted
import scooby # Reports Python environment

from pyincore import IncoreClient, Dataset, DataService

# %%
# To reload submodules need to use this magic command to set autoreload on
# %load_ext autoreload
# %autoreload 2
# open, read, and execute python program with reusable commands
from pyncoda.ncoda_00b_directory_design import directory_design
from pyncoda.ncoda_00e_geoutilities import spatial_join_points_to_poly
from pyncoda.ncoda_07a_generate_hui import generate_hui_functions
from pyncoda.ncoda_07c_generate_addpt import generate_addpt_functions
from pyncoda.ncoda_07d_run_hua_workflow import hua_workflow_functions

# %%
# Generate report of Python environment
print(scooby.Report(additional=['pandas','pyincore','pyincore_viz','ipyleaflet']))
# Out:
# --------------------------------------------------------------------------------
#   Date: Thu Feb 16 10:50:06 2023 Central Standard Time
#
#                 OS : Windows
#             CPU(s) : 12
#            Machine : AMD64
#       Architecture : 64bit
#                RAM : 31.6 GiB
#        Environment : Jupyter
#
#   Python 3.8.16 | packaged by conda-forge | (default, Feb  1 2023, 15:53:35)
#   [MSC v.1929 64 bit (AMD64)]
#
#             pandas : 1.5.3
#           pyincore : 1.8.0
#       pyincore_viz : 1.8.1
#         ipyleaflet : 0.17.2
#              numpy : 1.24.2
#              scipy : 1.10.0
#            IPython : 8.10.0
#         matplotlib : 3.6.3
#             scooby : 0.7.1
# --------------------------------------------------------------------------------

# %%
# Check working directory - good practice for relative path access
os.getcwd()
# Out:
# 'c:\\Users\\nathanael99\\MyProjects\\github\\intersect-community-data'

# %% [markdown]
# ### Required Information:
# #### Residential Building Variable
# What variable has information to determine if building is residential or not?
# County observations by variable

# %%
Nofal_residential_archetypes = { 
        1 : 'One-story sf residential building on a crawlspace foundation',
        2 : 'One-story mf residential building on a slab-on-grade foundation',
        3 : 'Two-story sf residential building on a crawlspace foundation',
        4 : 'Two-story mf residential building on a slab-on-grade foundation'}

Nofal_residential_archetypesv2 = { 
        1 : {'Description' : 
                'One-story sf residential building on a crawlspace foundation',
             'HU estimate' : 1},
        2 : {'Description' : 
                'One-story mf residential building on a slab-on-grade foundation',
              'HU estimate' : 1},
        3 : {'Description' : 
                'Two-story sf residential building on a crawlspace foundation',
            'HU estimate' : 1},
        4 : {'Description' : 
                'Two-story mf residential building on a slab-on-grade foundation',
            'HU estimate' : 1}
            }


# HAZUS Archetypes for residential buildings include an estimate of housing units
HAZUS_residential_archetypes = { 
    "RES1" : {'Description' : "Single Family Dwelling", 'HU estimate' : 1},
    "RES2" : {'Description' : "Mobile / Manufactured Home", 'HU estimate' : 1},
    "RES3A" : {'Description' : "Duplex", 'HU estimate' : 2},
    "RES3B" : {'Description' : "3-4 Units", 'HU estimate' : 3},
    "RES3C" : {'Description' : "5-9 Units", 'HU estimate' : 7},
    "RES3D" : {'Description' : "10-19 Units", 'HU estimate' : 15},
    "RES3E" : {'Description' : "20-49 Units", 'HU estimate' : 30},
    "RES3F" : {'Description' : "50+ Units", 'HU estimate' : 50},
    "RES4" : {'Description' : "Temporary Lodging", 'HU estimate' : 1},
    "RES5" : {'Description' : "Institutional Dormitory", 'HU estimate' : 1},
    "RES6" : {'Description' : "Nursing Home", 'HU estimate' : 1}
    }

# %%
# Edit Data Dictionary for Community

# Example of data dictionary for one community with one county
# Check how to capitalize the state name at
## https://www2.census.gov/geo/tiger/TIGER2020PL/STATE/

# NOTE on file path length. WINDOWS has a limit of 260 characters for file path length.
# Community name needs to be short to avoid this limit.

communities = {'Lumberton_NC' : {
                    'community_name' : 'Lumberton, NC',
                    'focalplace_name' : 'Lumberton',
                    'STATE' : 'NORTH_CAROLINA',
                    'years' : ['2010'],
                    'counties' : { 
                        1 : {'FIPS Code' : '37155', 'Name' : 'Robeson County, NC'}},
                    'building_inventory' : { 
                        'id' : '62ab7dcbf328861e25ffea9e',
                        'note' : 'Building inventory for Robeson County, NC',
                        'archetype_var' : 'archetype',
                        'residential_archetypes' : Nofal_residential_archetypesv2,
                        'building_area_var' : 'sq_foot'}
                                }
                }
communities = {'Galveston_TX' : {
                    'community_name' : 'Galveston, TX',
                    'focalplace_name' : 'Galveston',
                    'STATE' : 'TEXAS',
                    'years' : ['2010'],
                    'counties' : { 
                        1 : {'FIPS Code' : '48167', 'Name' : 'Galveston County, TX'}},
                    'building_inventory' : { 
                        'id' : '63053ddaf5438e1f8c517fed',
                        'note' : 'Building inventory for Galveston County, TX',
                        'archetype_var' : 'arch_flood',
                        'residential_archetypes' : Nofal_residential_archetypesv2,
                        'building_area_var' : 'sq_foot'}
                                }
                }

version = '2.0.0'
version_text = 'v2-0-0'

# Save Outputfolder - due to long folder name paths output saved to folder with shorter name
# files from this program will be saved with the program name - 
# this helps to follow the overall workflow
outputfolder = "OutputData"

# Set random seed for reproducibility
seed = 1000
basevintage = 2010

# %% [markdown]
# ## Step 1: Set up pyincore and read in data
# IN-CORE is an open source python package that can be used to model the resilience of a community. To download IN-CORE, see:
#
# https://incore.ncsa.illinois.edu/
#
# Registration is free.

# %%
client = IncoreClient()
# IN-CORE caches files on the local machine, it might be necessary to clear the memory
client.clear_cache()
# Out:
# Connection successful to IN-CORE services. pyIncore version detected: 1.8.0

# %%
# create data_service object for loading files
data_service = DataService(client)

# %% [markdown]
# ## Read in Housing Unit Inventory or create a new one

# %%
generate_hui_df = generate_hui_functions(
                    communities =   communities,
                    seed =          seed,
                    version =       version,
                    version_text=   version_text,
                    basevintage=    basevintage,
                    outputfolder=   outputfolder
                    )

hui_dataset_id = generate_hui_df.generate_hui_v2_for_incore()

# Housing Unit inventory
housing_unit_inv_id = hui_dataset_id
# load housing unit inventory as pandas dataframe
housing_unit_inv = Dataset.from_data_service(housing_unit_inv_id, data_service)
filename = housing_unit_inv.get_file_path('csv')
print("The IN-CORE Dataservice has saved the Housing Unit Inventory on your local machine: "+filename)

# Convert CSV to Pandas Dataframe
housing_unit_inv_df = pd.read_csv(filename, header="infer")
# Out:
# Generating Housing Unit Inventory v2.0.0 data for Galveston, TX
# Connection successful to IN-CORE services. pyIncore version detected: 1.8.0
# Number of datasets matching Housing Unit Inventory v2.0.0 data for Galveston, TX: 1
# Dataset Housing Unit Inventory v2.0.0 data for Galveston, TX already exists in IN-CORE
# Dataset already exists in IN-CORE with filename hui_v2-0-0_Galveston_TX_2010_rs1000.csv
# Use dataset_id: 626322a7e74a5c2dfb3a72b0
# Dataset already exists on IN-CORE, use dataset_id: 626322a7e74a5c2dfb3a72b0
# The IN-CORE Dataservice has saved the Housing Unit Inventory on your local machine: C:\Users\nathanael99\.incore\cache_data\648c22dd689743dc9dedf242006adc5a9c21de9a89c016323dccfedef94f7737\626322a7e74a5c2dfb3a72b0\hui_v2-0-0_Galveston_TX_2010_rs1000\hui_v2-0-0_Galveston_TX_2010_rs1000.csv

# %% [markdown]
# ## Generate Address Point Inventory

# %%
for community in communities.keys():
    # Building inventory ID
    bldg_inv_id = communities[community]['building_inventory']['id']
    archetype_var = communities[community]['building_inventory']['archetype_var']
    building_area_var = communities[community]['building_inventory']['building_area_var']
    residential_archetypes = communities[community]['building_inventory']['residential_archetypes']
    # load building inventory
    bldg_inv = Dataset.from_data_service(bldg_inv_id, data_service)
    filename = bldg_inv.get_file_path('shp')
    print("The IN-CORE Dataservice has saved the Building Inventory on your local machine: "+filename)
    bldg_inv_gdf = gpd.read_file(filename)

    print("Generate Address point inventory for: "+community)
    print("Based on building inventory: "+bldg_inv_id)
    generate_addpt_df = generate_addpt_functions(
                        community =   community,
                        communities = communities,
                        hui_df = housing_unit_inv_df,
                        bldg_inv_gdf = bldg_inv_gdf,
                        bldg_inv_id = bldg_inv_id,
                        residential_archetypes = residential_archetypes,
                        archetype_var = archetype_var,
                        building_area_var = building_area_var,
                        building_area_cutoff = 300,
                        seed =          seed,
                        version =       version,
                        version_text=   version_text,
                        basevintage=    basevintage,
                        outputfolder=   outputfolder
                        )

    addpt_dataset_id = generate_addpt_df.generate_addpt_v2_for_incore()

    ### Read in Address Point Inventory
    '''
    The address point inventory is an intermediate file based on the building inventory. 
    The address point inventory acts as the bridge between the building inventory 
    and the housing unit inventory.
    '''
    # Check if addpt_dataset_id is string
    if isinstance(addpt_dataset_id, str):
        print("The Address Point Inventory ID is a pandas string")
        # Address Point inventory
        addpt_inv_id = addpt_dataset_id
        # load housing unit inventory as pandas dataframe
        addpt_inv = Dataset.from_data_service(addpt_inv_id, data_service)
        filename = addpt_inv.get_file_path('csv')
        print("The IN-CORE Dataservice has saved the Address Point Inventory on your local machine: "+filename)
        addpt_inv_df = pd.read_csv(filename, header="infer")
    # else if addpt_dataset_id is a dataframe
    elif isinstance(addpt_dataset_id, pd.DataFrame):
        addpt_inv_df = addpt_dataset_id
        print("The Address Point Inventory ID contains a pandas dataframe")
    else:
        print("The Address Point Inventory is not a string or pandas dataframe")

    '''
    ### Run Housing Unit Allocation
    '''

    print("Housing Unit Allocation for: "+community)
    print("Based on housing unit inventory: "+hui_dataset_id)
    print("Based on building inventory: "+bldg_inv_id)

    outputfolders = directory_design(state_county_name = community,
                                            outputfolder = outputfolder)

    run_hua_gdf = hua_workflow_functions(
                        community =   community,
                        hui_df = housing_unit_inv_df,
                        bldg_gdf = bldg_inv_gdf,
                        addpt_df = addpt_inv_df,
                        seed =          seed,
                        version =       version,
                        version_text=   version_text,
                        basevintage=    basevintage,
                        outputfolder=   outputfolder,
                        outputfolders = outputfolders
                        )

    hua_gdf = run_hua_gdf.housing_unit_allocation_workflow()

    ## Merge Housing Unit Allocation with Housing Unit Inventory
    # Merge HUA with HUI
    hua_cols = ['huid','guid','placeNAME10','huestimate','x','y']
    hua_hui_df = pd.merge(left = housing_unit_inv_df,
                        right = hua_gdf[hua_cols],
                        on='huid',
                        how='left')

    # Replace missing guid 
    hua_hui_df['guid'] = hua_hui_df['guid'].fillna('missing building id')

    ## Save Housing Unit Allocation to CSV and Upload to IN-CORE Dataservice
    # save hua_hui_gdf to csv
    check_folder = outputfolder
    output_filename = f'hua_{version_text}_{community}_{basevintage}_rs{seed}_{bldg_inv_id}'
    csv_filepath = check_folder+"/"+output_filename+'.csv'
    savefile = sys.path[0]+"/"+csv_filepath
    # Resave results for community name
    hua_hui_df.to_csv(savefile, index=False)

    # make a county list for community
    county_list = ''
    for county in communities[community]['counties'].keys():
        state_county = communities[community]['counties'][county]['FIPS Code']
        state_county_name  = communities[community]['counties'][county]['Name']
        print(state_county_name,': county FIPS Code',state_county)
        county_list = county_list + state_county_name+': county FIPS Code '+state_county
    county_list
    
    title = "Housing Unit Allocation v2.0.0 data for "+community + " " + str(basevintage)
    title

    # Upload to IN-CORE Dataservice
    run_hua_gdf.upload_hua_file_to_incore(title =title,
                        county_list = county_list,
                        csv_filepath = csv_filepath,
                        output_filename = output_filename)
# Out:
# The IN-CORE Dataservice has saved the Building Inventory on your local machine: C:\Users\nathanael99\.incore\cache_data\648c22dd689743dc9dedf242006adc5a9c21de9a89c016323dccfedef94f7737\63053ddaf5438e1f8c517fed\galveston_bldgs_w_guid\galveston_bldgs_w_guid.shp
# Generate Address point inventory for: Galveston_TX
# Based on building inventory: 63053ddaf5438e1f8c517fed
# ***************
# Address Point Inventory Workflow
# ***************
#
# Generating Address Point Inventory v2.0.0 data for Galveston_TX 2010
# Connection successful to IN-CORE services. pyIncore version detected: 1.8.0
# Number of datasets matching Address Point Inventory v2.0.0 data for Galveston_TX 2010: 0
# Dataset Address Point Inventory v2.0.0 data for Galveston_TX 2010 does not exist in IN-CORE
# ***************
# Obtaining Census Block, Place, and PUMA Data
# ***************
#
# Galveston County, TX : county FIPS Code 48167
# Creating folder OutputData/GalvestonCounty_TX to store output.
# Creating folder OutputData/GalvestonCounty_TX/00_logfiles
#      logfiles Folder purpose: Store text files with log of workflow.
# Creating folder OutputData/GalvestonCounty_TX/01_CommunitySourceData
#      CommunitySourceData Folder purpose: Source source data files. Helps with software development and replication.
# Creating folder OutputData/GalvestonCounty_TX/02_TidyCommunitySourceData
#      TidyCommunitySourceData Folder purpose: Cleaned source data and inputs for base inventory.
# Creating folder OutputData/GalvestonCounty_TX/03_BaseInventory
#      BaseInventory Folder purpose: Initial inventories before random merge. Use as inputs to uncertainty propagation.
# Creating folder OutputData/GalvestonCounty_TX/04_RandomMerge
#      RandomMerge Folder purpose: Results of random merge with flag columns.
# Creating folder OutputData/GalvestonCounty_TX/05_Verify
#      Verify Folder purpose: Results to compare inventories with source data.
# Creating folder OutputData/GalvestonCounty_TX/06_Explore
#      Explore Folder purpose: Explore output results.
# Creating folder OutputData/GalvestonCounty_TX/07_Uncertainty_propagation
#      Uncertainty_propagation Folder purpose: Results of MCS to determine which random seed to use for validation.
# Creating folder OutputData/GalvestonCounty_TX/08_Validation
#      Validation Folder purpose: Application using inventory e.g. IN-CORE.
# Checking if file exists: OutputData/GalvestonCounty_TX/01_CommunitySourceData/tl_2010_48167_tabblockplacepuma10EPSG4269.csv
# Creating block data for  48167
# Obtaining Census block data from: https://www2.census.gov/geo/tiger/TIGER2020PL/STATE/48_TEXAS/48167/tl_2020_48167_tabblock10.zip
# Obtaining Census place data from: https://www2.census.gov/geo/tiger/TIGER2010/PLACE/2010/tl_2010_48_place10.zip
# Obtaining Census puma data from: https://www2.census.gov/geo/tiger/TIGER2010/PUMA5/2010/tl_2010_48_puma10.zip
# Spatially Join place Columns ['GEOID10', 'NAME10', 'NAMELSAD10'] with Block Data.
# Polygon file has 1752 place polygons.
# Identified 26 place polygons to spatially join.
# Spatially Join puma Columns ['GEOID10', 'NAMELSAD10'] with Block Data.
# Polygon file has 212 puma polygons.
# Identified 10 puma polygons to spatially join.
# ***************
# Predicting Housing Unit Estimates
# ***************
#
# Polygon file has 9595 block polygons.
# Identified 9584 block polygons to spatially join.
# ................................................................................................51507 Buildings have Residential Archetype 1
# 68616 Buildings have Residential Archetype 2
# 12881 Buildings have Residential Archetype 3
# 28391 Buildings have Residential Archetype 4
# 15057 Buildings have building_area_var less than 300
# 0 Buildings have  sq_foot _by_AP less than 300
# 147360 Buildings assigned residential.
# Total number of expected housing unit address points in county: 132553
# 8007 buildings are in blocks with no housing units.
# For Round 1 Estimated Residential Address Points correlation: 0.651
# 1. HU=0 had 1324 observations
# 2. HU=AP had 837 observations
# 3. HU<AP had 3690 observations
# 8. HU > 0, Building Count = Missing had 0 observations
# 9. HU > 0, Building Count = 0 had 114 observations
# 10. HU = 0, Building Count = Missing had 0 observations
# 5. HU > 0, AP = 0 had 127 observations
# 4. HU>AP had 1259 observations
# 6. HU > 0, AP = Missing, But buildings present had 0 observations
# 7. HU > 0, AP = Missing had 0 observations
# 712 buildings with error 5. HU > 0, AP = 0.
# 13112 buildings with error 2. HU=AP
# 128057 buildings with error 3. HU<AP.
# 114 buildings with error 9. no buildings for hu.
# 7980 buildings with error 1. HU=0.
# For Round 2 Estimated Residential Address Points correlation: 0.871
# 1. HU=0 had 1324 observations
# 2. HU=AP had 1220 observations
# 3. HU<AP had 3961 observations
# 8. HU > 0, Building Count = Missing had 0 observations
# 9. HU > 0, Building Count = 0 had 114 observations
# 10. HU = 0, Building Count = Missing had 0 observations
# 5. HU > 0, AP = 0 had 0 observations
# 4. HU>AP had 732 observations
# 6. HU > 0, AP = Missing, But buildings present had 0 observations
# 7. HU > 0, AP = Missing had 0 observations
# 13590 buildings updated huestimate by 1.
# 0 buildings updated huestimate by 1.
# For Round 3 Estimated Residential Address Points correlation: 0.882
# 1. HU=0 had 1324 observations
# 2. HU=AP had 1220 observations
# 3. HU<AP had 4693 observations
# 8. HU > 0, Building Count = Missing had 0 observations
# 9. HU > 0, Building Count = 0 had 114 observations
# 10. HU = 0, Building Count = Missing had 0 observations
# 5. HU > 0, AP = 0 had 0 observations
# 4. HU>AP had 0 observations
# 6. HU > 0, AP = Missing, But buildings present had 0 observations
# 7. HU > 0, AP = Missing had 0 observations
# Galveston County, TX : county FIPS Code 48167
# Total number of expected housing unit address points in county: 132553
# Converting HU Block Counts Dataframe block id to string
# Connection successful to IN-CORE services. pyIncore version detected: 1.8.0
# dataset is created with id 63ee60d162b9d001e6a2b65f
# The file(s): addpt_v2-0-0_Galveston_TX_2010_63053ddaf5438e1f8c517fed have been uploaded to IN-CORE
# Dataset now on IN-CORE, use dataset_id: 63ee60d162b9d001e6a2b65f
# Dataset is only in personal account, contact IN-CORE to make public
# The Address Point Inventory ID is a pandas string
# The IN-CORE Dataservice has saved the Address Point Inventory on your local machine: C:\Users\nathanael99\.incore\cache_data\648c22dd689743dc9dedf242006adc5a9c21de9a89c016323dccfedef94f7737\63ee60d162b9d001e6a2b65f\addpt_v2-0-0_Galveston_TX_2010_63053ddaf5438e1f8c517fed\addpt_v2-0-0_Galveston_TX_2010_63053ddaf5438e1f8c517fed.csv
# Housing Unit Allocation for: Galveston_TX
# Based on housing unit inventory: 626322a7e74a5c2dfb3a72b0
# Based on building inventory: 63053ddaf5438e1f8c517fed
# Creating folder OutputData/Galveston_TX to store output.
# Creating folder OutputData/Galveston_TX/00_logfiles
#      logfiles Folder purpose: Store text files with log of workflow.
# Creating folder OutputData/Galveston_TX/01_CommunitySourceData
#      CommunitySourceData Folder purpose: Source source data files. Helps with software development and replication.
# Creating folder OutputData/Galveston_TX/02_TidyCommunitySourceData
#      TidyCommunitySourceData Folder purpose: Cleaned source data and inputs for base inventory.
# Creating folder OutputData/Galveston_TX/03_BaseInventory
#      BaseInventory Folder purpose: Initial inventories before random merge. Use as inputs to uncertainty propagation.
# Creating folder OutputData/Galveston_TX/04_RandomMerge
#      RandomMerge Folder purpose: Results of random merge with flag columns.
# Creating folder OutputData/Galveston_TX/05_Verify
#      Verify Folder purpose: Results to compare inventories with source data.
# Creating folder OutputData/Galveston_TX/06_Explore
#      Explore Folder purpose: Explore output results.
# Creating folder OutputData/Galveston_TX/07_Uncertainty_propagation
#      Uncertainty_propagation Folder purpose: Results of MCS to determine which random seed to use for validation.
# Creating folder OutputData/Galveston_TX/08_Validation
#      Validation Folder purpose: Application using inventory e.g. IN-CORE.
# Running up Housing Unit Allocation for Galveston_TX
#
# ***************************************
#     Run Housing Unit Allocation for Galveston_TX
# ***************************************
#
#
# ***************************************
#     Merge housing unit and address point data with first 3 counters.
# ***************************************
#
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge hui on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'huicounter1', 'ownershp1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name huid
# Primary key variable huid is unique.
# Primary key huid has no missing values
# Initializing primary flag set variable for strctid
# New flag: strctid_flagsetrm
# ['huid', 'Block2010', 'blockid', 'bgid', 'tractid', 'FIPScounty', 'numprec', 'ownershp', 'race', 'hispan', 'family', 'vacancy', 'gqtype', 'incomegroup', 'hhinc', 'randincome', 'poverty', 'BLOCKID10_str', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3']
# Initializing geovar flag set variable for strctid at geolevel Block2010
# New flag: strctid_Block2010_flagsetrm
# Observations without primary flag set 132553
# Observations without geovar flag set 132553
# After updated observations without geovar flag set 132553
# Setting 132553 flags for data without strctid before merge.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp1
# Attempting random merge for 132553 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['huid']
# Sorting before random merge order by ['Block2010', 'huicounter1', 'ownershp1', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter1', 'ownershp1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name addptid
# Primary key variable addptid is unique.
# Primary key addptid has no missing values
# Initializing primary flag set variable for strctid
# New flag: strctid_flagsetrm
# ['addptid', 'Block2010', 'addrptid', 'guid', 'strctid', 'blockid', 'placeGEOID10', 'placeNAME10', 'COUNTYFP10', 'BLOCKID10_str', 'huestimate', 'residential', 'bldgobs', 'flag_ap', 'arch_flood', 'x', 'y', 'huicounter_addpt', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3']
# Initializing geovar flag set variable for strctid at geolevel Block2010
# New flag: strctid_Block2010_flagsetrm
# Observations without primary flag set 210678
# Observations without geovar flag set 210678
# After updated observations without geovar flag set 210678
# Setting 210678 flags for strctid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp1
# Attempting random merge for 210678 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['addptid']
# Sorting before random merge order by ['Block2010', 'huicounter1', 'ownershp1', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter1', 'ownershp1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'huicounter1', 'ownershp1', 'random_mergeorder']
# Primary data frame has extra strctid  observations with no match: 59761
# Observations with no match filled with -999
# Merge found extra strctid  observations: 137886
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['huid', 'Block2010', 'huicounter1', 'ownershp1', 'random_mergeorder', 'addptid', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'check_merge', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 270439
# Observations without geovar flag set 270439
# After updated observations without geovar flag set 270439
# Round = 1
# Setting 72792 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp1
# Observations geovar flag set 1 = 72792
# After Recombine flag set 1 = 72792
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 0
# Before update results observations flag set 1 = 72792
# After update observations geovar flag set 1 = 72792
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 72792
# Input and output data have the same length 132553
# Outputdata has 72792 Observations with predicted strctid
# Percent left to predict: 45.08
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 0
# Before update results observations flag set 1 = 72792
# After update observations geovar flag set 1 = 72792
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 72792
# Input and output data have the same length 210678
# Outputdata has 72792 Observations with predicted strctid
# Percent left to predict: 65.45
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  45.084608
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge hui on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'huicounter1', 'ownershp2']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name huid
# Primary key variable huid is unique.
# Primary key huid has no missing values
# ['huid', 'Block2010', 'blockid', 'bgid', 'tractid', 'FIPScounty', 'numprec', 'ownershp', 'race', 'hispan', 'family', 'vacancy', 'gqtype', 'incomegroup', 'hhinc', 'randincome', 'poverty', 'BLOCKID10_str', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 59761
# Observations without geovar flag set 59761
# After updated observations without geovar flag set 59761
# Setting 0 flags for strctid set before random merge.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp2
# Attempting random merge for 59761 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['huid']
# Sorting before random merge order by ['Block2010', 'huicounter1', 'ownershp2', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter1', 'ownershp2']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name addptid
# Primary key variable addptid is unique.
# Primary key addptid has no missing values
# ['addptid', 'Block2010', 'blockid', 'placeGEOID10', 'COUNTYFP10', 'BLOCKID10_str', 'residential', 'bldgobs', 'flag_ap', 'arch_flood', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 137886
# Observations without geovar flag set 137886
# After updated observations without geovar flag set 137886
# Setting 137886 flags for strctid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp2
# Attempting random merge for 137886 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['addptid']
# Sorting before random merge order by ['Block2010', 'huicounter1', 'ownershp2', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter1', 'ownershp2']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'huicounter1', 'ownershp2', 'random_mergeorder']
# Primary data frame has extra strctid  observations with no match: 56496
# Observations with no match filled with -999
# Merge found extra strctid  observations: 134621
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['huid', 'Block2010', 'huicounter1', 'ownershp2', 'random_mergeorder', 'addptid', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'check_merge', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 194382
# Observations without geovar flag set 194382
# After updated observations without geovar flag set 194382
# Round = 1
# Setting 3265 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp2
# Observations geovar flag set 1 = 3265
# After Recombine flag set 1 = 3265
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 72792
# Before update results observations flag set 1 = 3265
# After update observations geovar flag set 1 = 76057
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 76057
# Input and output data have the same length 132553
# Outputdata has 76057 Observations with predicted strctid
# Percent left to predict: 42.62
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 72792
# Before update results observations flag set 1 = 3265
# After update observations geovar flag set 1 = 76057
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 76057
# Input and output data have the same length 210678
# Outputdata has 76057 Observations with predicted strctid
# Percent left to predict: 63.90
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  42.621442
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge hui on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'huicounter1', 'ownershp3']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name huid
# Primary key variable huid is unique.
# Primary key huid has no missing values
# ['huid', 'Block2010', 'blockid', 'bgid', 'tractid', 'FIPScounty', 'numprec', 'ownershp', 'race', 'hispan', 'family', 'vacancy', 'gqtype', 'incomegroup', 'hhinc', 'randincome', 'poverty', 'BLOCKID10_str', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 56496
# Observations without geovar flag set 56496
# After updated observations without geovar flag set 56496
# Setting 0 flags for strctid set before random merge.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp3
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp3
# Attempting random merge for 56496 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['huid']
# Sorting before random merge order by ['Block2010', 'huicounter1', 'ownershp3', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter1', 'ownershp3']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name addptid
# Primary key variable addptid is unique.
# Primary key addptid has no missing values
# ['addptid', 'Block2010', 'blockid', 'placeGEOID10', 'COUNTYFP10', 'BLOCKID10_str', 'residential', 'bldgobs', 'flag_ap', 'arch_flood', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 134621
# Observations without geovar flag set 134621
# After updated observations without geovar flag set 134621
# Setting 134621 flags for strctid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp3
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp3
# Attempting random merge for 134621 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['addptid']
# Sorting before random merge order by ['Block2010', 'huicounter1', 'ownershp3', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter1', 'ownershp3']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'huicounter1', 'ownershp3', 'random_mergeorder']
# Primary data frame has extra strctid  observations with no match: 39859
# Observations with no match filled with -999
# Merge found extra strctid  observations: 117984
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['huid', 'Block2010', 'huicounter1', 'ownershp3', 'random_mergeorder', 'addptid', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'check_merge', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 174480
# Observations without geovar flag set 174480
# After updated observations without geovar flag set 174480
# Round = 1
# Setting 16637 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter1
# 0 observations do not have required variable ownershp3
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter1
# Setting 0 flags for observations without required variable ownershp3
# Observations geovar flag set 1 = 16637
# After Recombine flag set 1 = 16637
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 76057
# Before update results observations flag set 1 = 16637
# After update observations geovar flag set 1 = 92694
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 92694
# Input and output data have the same length 132553
# Outputdata has 92694 Observations with predicted strctid
# Percent left to predict: 30.07
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 76057
# Before update results observations flag set 1 = 16637
# After update observations geovar flag set 1 = 92694
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 92694
# Input and output data have the same length 210678
# Outputdata has 92694 Observations with predicted strctid
# Percent left to predict: 56.00
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  30.070236
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
#
# ***************************************
#    Update Predicted Tenure.
# ***************************************
#
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge hui on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'huicounter2', 'ownershp1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name huid
# Primary key variable huid is unique.
# Primary key huid has no missing values
# ['huid', 'Block2010', 'blockid', 'bgid', 'tractid', 'FIPScounty', 'numprec', 'ownershp', 'race', 'hispan', 'family', 'vacancy', 'gqtype', 'incomegroup', 'hhinc', 'randincome', 'poverty', 'BLOCKID10_str', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 39859
# Observations without geovar flag set 39859
# After updated observations without geovar flag set 39859
# Setting 0 flags for strctid set before random merge.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter2
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter2
# Setting 0 flags for observations without required variable ownershp1
# Attempting random merge for 39859 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['huid']
# Sorting before random merge order by ['Block2010', 'huicounter2', 'ownershp1', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter2', 'ownershp1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name addptid
# Primary key variable addptid is unique.
# Primary key addptid has no missing values
# ['addptid', 'Block2010', 'blockid', 'placeGEOID10', 'COUNTYFP10', 'BLOCKID10_str', 'residential', 'bldgobs', 'flag_ap', 'arch_flood', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 117984
# Observations without geovar flag set 117984
# After updated observations without geovar flag set 117984
# Setting 117984 flags for strctid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter2
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter2
# Setting 0 flags for observations without required variable ownershp1
# Attempting random merge for 117984 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['addptid']
# Sorting before random merge order by ['Block2010', 'huicounter2', 'ownershp1', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter2', 'ownershp1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'huicounter2', 'ownershp1', 'random_mergeorder']
# Primary data frame has extra strctid  observations with no match: 38184
# Observations with no match filled with -999
# Merge found extra strctid  observations: 116309
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['huid', 'Block2010', 'huicounter2', 'ownershp1', 'random_mergeorder', 'addptid', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'check_merge', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 156168
# Observations without geovar flag set 156168
# After updated observations without geovar flag set 156168
# Round = 1
# Setting 1675 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter2
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter2
# Setting 0 flags for observations without required variable ownershp1
# Observations geovar flag set 1 = 1675
# After Recombine flag set 1 = 1675
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 92694
# Before update results observations flag set 1 = 1675
# After update observations geovar flag set 1 = 94369
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 94369
# Input and output data have the same length 132553
# Outputdata has 94369 Observations with predicted strctid
# Percent left to predict: 28.81
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 92694
# Before update results observations flag set 1 = 1675
# After update observations geovar flag set 1 = 94369
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 94369
# Input and output data have the same length 210678
# Outputdata has 94369 Observations with predicted strctid
# Percent left to predict: 55.21
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  28.806591
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge hui on all common group vars.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'huicounter2', 'ownershp2']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name huid
# Primary key variable huid is unique.
# Primary key huid has no missing values
# ['huid', 'Block2010', 'blockid', 'bgid', 'tractid', 'FIPScounty', 'numprec', 'ownershp', 'race', 'hispan', 'family', 'vacancy', 'gqtype', 'incomegroup', 'hhinc', 'randincome', 'poverty', 'BLOCKID10_str', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 38184
# Observations without geovar flag set 38184
# After updated observations without geovar flag set 38184
# Setting 0 flags for strctid set before random merge.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter2
# 0 observations do not have required variable ownershp2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter2
# Setting 0 flags for observations without required variable ownershp2
# Attempting random merge for 38184 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['huid']
# Sorting before random merge order by ['Block2010', 'huicounter2', 'ownershp2', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter2', 'ownershp2']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name addptid
# Primary key variable addptid is unique.
# Primary key addptid has no missing values
# ['addptid', 'Block2010', 'blockid', 'placeGEOID10', 'COUNTYFP10', 'BLOCKID10_str', 'residential', 'bldgobs', 'flag_ap', 'arch_flood', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 116309
# Observations without geovar flag set 116309
# After updated observations without geovar flag set 116309
# Setting 116309 flags for strctid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter2
# 0 observations do not have required variable ownershp2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter2
# Setting 0 flags for observations without required variable ownershp2
# Attempting random merge for 116309 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['addptid']
# Sorting before random merge order by ['Block2010', 'huicounter2', 'ownershp2', 'random_order']
# Generating random merge order by ['Block2010', 'huicounter2', 'ownershp2']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'huicounter2', 'ownershp2', 'random_mergeorder']
# Primary data frame has extra strctid  observations with no match: 35781
# Observations with no match filled with -999
# Merge found extra strctid  observations: 113906
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['huid', 'Block2010', 'huicounter2', 'ownershp2', 'random_mergeorder', 'addptid', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'check_merge', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 152090
# Observations without geovar flag set 152090
# After updated observations without geovar flag set 152090
# Round = 1
# Setting 2403 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable huicounter2
# 0 observations do not have required variable ownershp2
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable huicounter2
# Setting 0 flags for observations without required variable ownershp2
# Observations geovar flag set 1 = 2403
# After Recombine flag set 1 = 2403
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 94369
# Before update results observations flag set 1 = 2403
# After update observations geovar flag set 1 = 96772
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 96772
# Input and output data have the same length 132553
# Outputdata has 96772 Observations with predicted strctid
# Percent left to predict: 26.99
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 94369
# Before update results observations flag set 1 = 2403
# After update observations geovar flag set 1 = 96772
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 96772
# Input and output data have the same length 210678
# Outputdata has 96772 Observations with predicted strctid
# Percent left to predict: 54.07
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  26.993731
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# ...
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 99309
# Input and output data have the same length 132553
# Outputdata has 99309 Observations with predicted strctid
# Percent left to predict: 25.08
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 99309
# Before update results observations flag set 1 = 0
# After update observations geovar flag set 1 = 99309
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 99309
# Input and output data have the same length 210678
# Outputdata has 99309 Observations with predicted strctid
# Percent left to predict: 52.86
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  25.079779
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge almost complete.
# ***************************************
#
# Check primary and secondary files to understand why merge is not complete
#
# ***************************************
#    Update Predicted Tenure.
# ***************************************
#
#
# ***************************************
#     Merge housing unit and address point data with first no counters.
# ***************************************
#
# Round 1
#
# ***************************************
# ***************************************
#
# Performing random merge at geography level: Block
#
# ***************************************
# ***************************************
#
#
# ***************************************
# ***************************************
#
# Attempt to merge hui without counter.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010', 'ownershp1']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name huid
# Primary key variable huid is unique.
# Primary key huid has no missing values
# ['huid', 'Block2010', 'blockid', 'bgid', 'tractid', 'FIPScounty', 'numprec', 'ownershp', 'race', 'hispan', 'family', 'vacancy', 'gqtype', 'incomegroup', 'hhinc', 'randincome', 'poverty', 'BLOCKID10_str', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 33244
# Observations without geovar flag set 33244
# After updated observations without geovar flag set 33244
# Setting 0 flags for strctid set before random merge.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable ownershp1
# Attempting random merge for 33244 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['huid']
# Sorting before random merge order by ['Block2010', 'ownershp1', 'random_order']
# Generating random merge order by ['Block2010', 'ownershp1']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name addptid
# Primary key variable addptid is unique.
# Primary key addptid has no missing values
# ['addptid', 'Block2010', 'blockid', 'placeGEOID10', 'COUNTYFP10', 'BLOCKID10_str', 'residential', 'bldgobs', 'flag_ap', 'arch_flood', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 111369
# Observations without geovar flag set 111369
# After updated observations without geovar flag set 111369
# Setting 111369 flags for strctid secondary data not used.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable ownershp1
# Attempting random merge for 111369 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['addptid']
# Sorting before random merge order by ['Block2010', 'ownershp1', 'random_order']
# Generating random merge order by ['Block2010', 'ownershp1']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'ownershp1', 'random_mergeorder']
# Primary data frame has extra strctid  observations with no match: 33244
# Observations with no match filled with -999
# Merge found extra strctid  observations: 111369
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['huid', 'Block2010', 'ownershp1', 'random_mergeorder', 'addptid', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'check_merge', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 144613
# Observations without geovar flag set 144613
# After updated observations without geovar flag set 144613
# Round = 1
# Setting 0 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# 0 observations do not have required variable ownershp1
# Setting 0 flags for observations without required variable Block2010
# Setting 0 flags for observations without required variable ownershp1
# Observations geovar flag set 1 = 0
# After Recombine flag set 1 = 0
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 99309
# Before update results observations flag set 1 = 0
# After update observations geovar flag set 1 = 99309
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 99309
# Input and output data have the same length 132553
# Outputdata has 99309 Observations with predicted strctid
# Percent left to predict: 25.08
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 1 = 99309
# Before update results observations flag set 1 = 0
# After update observations geovar flag set 1 = 99309
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 99309
# Input and output data have the same length 210678
# Outputdata has 99309 Observations with predicted strctid
# Percent left to predict: 52.86
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:  25.079779
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
# ***************************************
#
# Attempt to merge hui by geolevel only.
#
# ***************************************
# ***************************************
#
# Running random merge by ['Block2010']
#
# ***************************************
#     Setting up  primary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 481677262002078
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name huid
# Primary key variable huid is unique.
# Primary key huid has no missing values
# ['huid', 'Block2010', 'blockid', 'bgid', 'tractid', 'FIPScounty', 'numprec', 'ownershp', 'race', 'hispan', 'family', 'vacancy', 'gqtype', 'incomegroup', 'hhinc', 'randincome', 'poverty', 'BLOCKID10_str', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 33244
# Observations without geovar flag set 33244
# After updated observations without geovar flag set 33244
# Setting 0 flags for strctid set before random merge.
# 0 observations do not have required variable Block2010
# Setting 0 flags for observations without required variable Block2010
# Attempting random merge for 33244 primary observations.
#
# ***************************************
#     Preparing primary by NA data for random merge.
# ***************************************
#
# Sorting by  ['huid']
# Sorting before random merge order by ['Block2010', 'random_order']
# Generating random merge order by ['Block2010']
#
# ***************************************
#     Setting up  secondary data with primary key and flags
# ***************************************
#
# Adding Block2010 to column list
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Geolevels available []
# Geolvarids available ['Block2010']
# Adding Block2010 expected length 15
# Dataframe has Block 2010 for new geovar Block2010
# Confirming Block2010 has expected length.
# Longest Block2010 : 999999999999999
# Block2010 Expected Length 15 Available Length 15
# Checking primary key name addptid
# Primary key variable addptid is unique.
# Primary key addptid has no missing values
# ['addptid', 'Block2010', 'blockid', 'placeGEOID10', 'COUNTYFP10', 'BLOCKID10_str', 'residential', 'bldgobs', 'flag_ap', 'arch_flood', 'huicounter1', 'huicounter2', 'huicounter3', 'ownershp1', 'ownershp2', 'ownershp3', 'strctid', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y']
# Observations without primary flag set 111369
# Observations without geovar flag set 111369
# After updated observations without geovar flag set 111369
# Setting 111369 flags for strctid secondary data not used.
# 0 observations do not have required variable Block2010
# Setting 0 flags for observations without required variable Block2010
# Attempting random merge for 111369 secondary observations.
#
# ***************************************
#     Preparing secondary by NA data for random merge.
# ***************************************
#
# Sorting by  ['addptid']
# Sorting before random merge order by ['Block2010', 'random_order']
# Generating random merge order by ['Block2010']
# NA
#
# ***************************************
#     Random Merge primary with secondary by NA
# ***************************************
#
# Check merge vars includes geovarid: ['Block2010', 'random_mergeorder']
# Primary data frame has extra strctid  observations with no match: 0
# Observations with no match filled with -999
# Merge found extra strctid  observations: 78125
#
# ***************************************
#     Set Flags after Merge
# ***************************************
#
# ['huid', 'Block2010', 'random_mergeorder', 'addptid', 'strctid', 'addrptid', 'guid', 'huestimate', 'huicounter_addpt', 'placeNAME10', 'x', 'y', 'check_merge', 'strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Observations without primary flag set 111369
# Observations without geovar flag set 111369
# After updated observations without geovar flag set 111369
# Round = 2
# Setting 33244 flags for observations set by random merge using both primary and secondary data.
# Setting 0 flags for observations set by random merge using only primary data.
# 0 observations do not have required variable Block2010
# Setting 0 flags for observations without required variable Block2010
# Observations geovar flag set 2 = 33244
# After Recombine flag set 2 = 33244
#
# ***************************************
#    Generate output data
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 2 = 0
# Before update results observations flag set 2 = 33244
# After update observations geovar flag set 2 = 33244
#
# ***************************************
#     Check random merge results for primary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 132553
# Input and output data have the same length 132553
# Outputdata has 132553 Observations with predicted strctid
# Percent left to predict:  0.00
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
# Flag vars available ['strctid_flagsetrm', 'strctid_Block2010_flagsetrm']
# Before update output_df observations flag set 2 = 0
# Before update results observations flag set 2 = 33244
# After update observations geovar flag set 2 = 33244
#
# ***************************************
#     Check random merge results for secondary data.
# ***************************************
#
# Check by geovar flag strctid_Block2010_flagsetrm
# Observations flag not equal to 0 132553
# Input and output data have the same length 210678
# Outputdata has 132553 Observations with predicted strctid
# Percent left to predict: 37.08
#
# ***************************************
#     Overwrite input data with update output data.
# ***************************************
#
#
# +++++++++++++++++++++++++++++++++++++++
# Percent left to predict:   0.000000
#
# +++++++++++++++++++++++++++++++++++++++
#
# ***************************************
#     Random merge complete.
# ***************************************
#
# Save primary and secondary files with all columns
# Galveston County, TX : county FIPS Code 48167
# Connection successful to IN-CORE services. pyIncore version detected: 1.8.0
# dataset is created with id 63ee615d62b9d001e6a2b660
# The file(s): hua_v2-0-0_Galveston_TX_2010_rs1000_63053ddaf5438e1f8c517fed have been uploaded to IN-CORE
# Dataset now on IN-CORE, use dataset_id: 63ee615d62b9d001e6a2b660
# Dataset is only in personal account, contact IN-CORE to make public

# %%
#addpt_inv_df = pd.read_csv(filename, header="infer")
addpt_inv_df['addrptid'].describe()
# Out:
# count                                             210678
# unique                                            210678
# top       ST1815653a-7b70-44ce-8544-e975596bdf82AP000000
# freq                                                   1
# Name: addrptid, dtype: object

# %% [markdown]
# ## Explore and Validate Housing Unit Allocation

# %%
hua_gdf.head()
# Out:
#                    huid        Block2010       blockid          bgid  \
# 0  B481677201001000H001  481677201001000  4.816772e+14  4.816772e+11
# 1  B481677201001000H002  481677201001000  4.816772e+14  4.816772e+11
# 2  B481677201001000H003  481677201001000  4.816772e+14  4.816772e+11
# 3  B481677201001000H004  481677201001000  4.816772e+14  4.816772e+11
# 4  B481677201001000H005  481677201001000  4.816772e+14  4.816772e+11
#
#         tractid  FIPScounty  numprec  ownershp  race  hispan  ...  \
# 0  4.816772e+10     48167.0      1.0       1.0   1.0     0.0  ...
# 1  4.816772e+10     48167.0      1.0       1.0   1.0     0.0  ...
# 2  4.816772e+10     48167.0      1.0       1.0   1.0     0.0  ...
# 3  4.816772e+10     48167.0      1.0       1.0   1.0     0.0  ...
# 4  4.816772e+10     48167.0      1.0       1.0   1.0     0.0  ...
#
#    strctid_Block2010_flagsetrm  \
# 0                          1.0
# 1                          1.0
# 2                          1.0
# 3                          1.0
# 4                          1.0
#
#                                          addrptid  \
# 0  ST2290ae5b-99e1-46d2-b6cb-f4dde1c2ed51AP000000
# 1  ST3c985a93-c848-40c8-835a-85184f69bbb4AP000000
# 2  ST7c6fe5f4-d96a-4304-8267-7a1dcde7ec91AP000000
# 3  ST314a358e-186c-4a6b-9e41-d15edf4adb95AP000000
# 4  STb1a887d1-b151-4bce-b555-da24e0dabbf5AP000000
#
#                                    guid  huestimate  huicounter_addpt  \
# 0  2290ae5b-99e1-46d2-b6cb-f4dde1c2ed51         1.0               1.0
# 1  3c985a93-c848-40c8-835a-85184f69bbb4         1.0               1.0
# 2  7c6fe5f4-d96a-4304-8267-7a1dcde7ec91         1.0               1.0
# 3  314a358e-186c-4a6b-9e41-d15edf4adb95         1.0               1.0
# 4  b1a887d1-b151-4bce-b555-da24e0dabbf5         1.0               1.0
#
#    placeNAME10          x          y  archetype                    geometry
# 0  Friendswood -95.202090  29.556617        0.0  POINT (-95.20209 29.55662)
# 1  Friendswood -95.215403  29.554199        0.0  POINT (-95.21540 29.55420)
# 2  Friendswood -95.211325  29.557518        0.0  POINT (-95.21133 29.55752)
# 3  Friendswood -95.210067  29.555272        0.0  POINT (-95.21007 29.55527)
# 4  Friendswood -95.208705  29.557569        0.0  POINT (-95.20871 29.55757)
#
# [5 rows x 36 columns]

# %%
hua_gdf.head(1).T
# Out:
#                                                                           0
# huid                                                   B481677201001000H001
# Block2010                                                   481677201001000
# blockid                                                   481677201001000.0
# bgid                                                         481677201001.0
# tractid                                                       48167720100.0
# FIPScounty                                                          48167.0
# numprec                                                                 1.0
# ownershp                                                                1.0
# race                                                                    1.0
# hispan                                                                  0.0
# family                                                                  0.0
# vacancy                                                                 0.0
# gqtype                                                                  0.0
# incomegroup                                                             6.0
# hhinc                                                                   3.0
# randincome                                                          31459.0
# poverty                                                                 0.0
# BLOCKID10_str                                              B481677201001000
# huicounter1                                                             1.0
# huicounter2                                                             2.0
# huicounter3                                                             3.0
# ownershp1                                                               1.0
# ownershp2                                                               1.0
# ownershp3                                                               1.0
# strctid                              ST2290ae5b-99e1-46d2-b6cb-f4dde1c2ed51
# strctid_flagsetrm                                                       1.0
# strctid_Block2010_flagsetrm                                             1.0
# addrptid                     ST2290ae5b-99e1-46d2-b6cb-f4dde1c2ed51AP000000
# guid                                   2290ae5b-99e1-46d2-b6cb-f4dde1c2ed51
# huestimate                                                              1.0
# huicounter_addpt                                                        1.0
# placeNAME10                                                     Friendswood
# x                                                                 -95.20209
# y                                                                 29.556617
# archetype                                                               0.0
# geometry                       POINT (-95.2020898862915 29.556616989339922)

# %%
# describe the housing unit allocation primary keys and foreign keys
hua_gdf[['huid','Block2010','addrptid','guid','strctid']].astype(str).describe().T
# Out:
#             count  unique              top   freq
# huid       197527  132554              nan  64974
# Block2010  197527    6028  999999999999999  64974
# addrptid   197527  132554              nan  64974
# guid       197527  172535              nan    566
# strctid    197527  107675              nan  64974

# %% [markdown]
# ### Look at population characteristics and compare to US Census

# %%
# convert hui_hua_df to geodataframe
crs = "EPSG:4326"
hua_hui_gdf = gpd.GeoDataFrame(hua_hui_df, 
    geometry=gpd.points_from_xy(hua_hui_df.x, hua_hui_df.y), crs=crs)

# %%
from pyncoda.ncoda_04c_poptableresults import *
from pyncoda.ncoda_00d_cleanvarsutils import *

# %%
where = communities[community]['county']['name']
where
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 where = communities[community]['county']['name']
#       2 where
#
# KeyError: 'county'

# %%
PopResultsTable.pop_results_table(
                  input_df = hua_hui_gdf, 
                  who = "Total Population by Households", 
                  what = "by Race, Ethnicity",
                  where = where,
                  when = "2010",
                  row_index = "Race Ethnicity",
                  col_index = 'Tenure Status')
# Out:
# <style type="text/css">
# #T_58c0c caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_58c0c">
#   <caption>Table. Total Population by Households by Race, Ethnicity, Galveston, TX, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Tenure Status</th>
#       <th id="T_58c0c_level0_col0" class="col_heading level0 col0" >1 Owner Occupied (%)</th>
#       <th id="T_58c0c_level0_col1" class="col_heading level0 col1" >2 Renter Occupied (%)</th>
#       <th id="T_58c0c_level0_col2" class="col_heading level0 col2" >Total Population by Households (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race Ethnicity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58c0c_level0_row0" class="row_heading level0 row0" >1 White alone, Not Hispanic</th>
#       <td id="T_58c0c_row0_col0" class="data row0 col0" >137,132	 (67.3%)</td>
#       <td id="T_58c0c_row0_col1" class="data row0 col1" >37,790	 (46.2%)</td>
#       <td id="T_58c0c_row0_col2" class="data row0 col2" >174,922	 (61.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_58c0c_level0_row1" class="row_heading level0 row1" >2 Black alone, Not Hispanic</th>
#       <td id="T_58c0c_row1_col0" class="data row1 col0" >19,133	 (9.4%)</td>
#       <td id="T_58c0c_row1_col1" class="data row1 col1" >18,286	 (22.4%)</td>
#       <td id="T_58c0c_row1_col2" class="data row1 col2" >37,419	 (13.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_58c0c_level0_row2" class="row_heading level0 row2" >3 American Indian and Alaska Native alone, Not Hispanic</th>
#       <td id="T_58c0c_row2_col0" class="data row2 col0" >745	 (0.4%)</td>
#       <td id="T_58c0c_row2_col1" class="data row2 col1" >360	 (0.4%)</td>
#       <td id="T_58c0c_row2_col2" class="data row2 col2" >1,105	 (0.4%)</td>
#     </tr>
#     <tr>
#       <th id="T_58c0c_level0_row3" class="row_heading level0 row3" >4 Asian alone, Not Hispanic</th>
#       <td id="T_58c0c_row3_col0" class="data row3 col0" >6,304	 (3.1%)</td>
#       <td id="T_58c0c_row3_col1" class="data row3 col1" >1,717	 (2.1%)</td>
#       <td id="T_58c0c_row3_col2" class="data row3 col2" >8,021	 (2.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_58c0c_level0_row4" class="row_heading level0 row4" >5 Other Race, Not Hispanic</th>
#       <td id="T_58c0c_row4_col0" class="data row4 col0" >2,000	 (1.0%)</td>
#       <td id="T_58c0c_row4_col1" class="data row4 col1" >931	 (1.1%)</td>
#       <td id="T_58c0c_row4_col2" class="data row4 col2" >2,931	 (1.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_58c0c_level0_row5" class="row_heading level0 row5" >6 Any Race, Hispanic</th>
#       <td id="T_58c0c_row5_col0" class="data row5 col0" >38,504	 (18.9%)</td>
#       <td id="T_58c0c_row5_col1" class="data row5 col1" >22,633	 (27.7%)</td>
#       <td id="T_58c0c_row5_col2" class="data row5 col2" >61,137	 (21.4%)</td>
#     </tr>
#     <tr>
#       <th id="T_58c0c_level0_row6" class="row_heading level0 row6" >Total</th>
#       <td id="T_58c0c_row6_col0" class="data row6 col0" >203,818	 (100.0%)</td>
#       <td id="T_58c0c_row6_col1" class="data row6 col1" >81,717	 (100.0%)</td>
#       <td id="T_58c0c_row6_col2" class="data row6 col2" >285,535	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
# add category for missing building id
buildingdata_conditions = {'cat_var' : {'variable_label' : 'Building Data Availability',
                         'notes' : 'Does Housing Unit have building data?'},
              'condition_list' : {
                1 : {'condition': "(df['guid'] == 'missing building id')", 'value_label': "0 Missing Building Data"},
                2 : {'condition': "(df['guid'] != 'missing building id')", 'value_label': "1 Building Data Available"}}
            }
hua_hui_gdf = add_label_cat_conditions_df(hua_hui_gdf, conditions = buildingdata_conditions)
# Out:
# 0 Missing Building Data had 566 observations
# 1 Building Data Available had 131987 observations

# %%
hua_hui_gdf.head(1).T
# Out:
#                                                                           0
# huid                                                   B481677201001000H001
# blockid                                                     481677201001000
# bgid                                                           481677201001
# tractid                                                         48167720100
# FIPScounty                                                            48167
# numprec                                                                   1
# ownershp                                                                1.0
# race                                                                    1.0
# hispan                                                                  0.0
# family                                                                  0.0
# vacancy                                                                   0
# gqtype                                                                    0
# incomegroup                                                               6
# hhinc                                                                     3
# randincome                                                          31459.0
# poverty                                                                 0.0
# BLOCKID10_str                                              B481677201001000
# guid                                   2290ae5b-99e1-46d2-b6cb-f4dde1c2ed51
# placeNAME10                                                     Friendswood
# huestimate                                                              1.0
# x                                                                 -95.20209
# y                                                                 29.556617
# geometry                        POINT (-95.2020898862915 29.55661698933992)
# Building Data Availability_int                                          2.0
# Building Data Availability_str                    1 Building Data Available

# %%
PopResultsTable.pop_results_table(hua_hui_gdf, 
                  who = "Total Population by Households", 
                  what = "by Race, Ethnicity",
                  where = where,
                  when = "2010",
                  row_index = "Race Ethnicity",
                  col_index = 'Building Data Availability_str',
                  row_percent = '0 Missing Building Data')
# Out:
# <style type="text/css">
# #T_7fc92 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_7fc92">
#   <caption>Table. Total Population by Households by Race, Ethnicity, Galveston, TX, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Building Data Availability_str</th>
#       <th id="T_7fc92_level0_col0" class="col_heading level0 col0" >0 Missing Building Data (%)</th>
#       <th id="T_7fc92_level0_col1" class="col_heading level0 col1" >1 Building Data Available (%)</th>
#       <th id="T_7fc92_level0_col2" class="col_heading level0 col2" >Total Population by Households (%)</th>
#       <th id="T_7fc92_level0_col3" class="col_heading level0 col3" >Percent Row
# 0 Missing Building Data</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race Ethnicity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fc92_level0_row0" class="row_heading level0 row0" >1 White alone, Not Hispanic</th>
#       <td id="T_7fc92_row0_col0" class="data row0 col0" >409	 (44.9%)</td>
#       <td id="T_7fc92_row0_col1" class="data row0 col1" >174,513	 (60.4%)</td>
#       <td id="T_7fc92_row0_col2" class="data row0 col2" >174,922	 (60.4%)</td>
#       <td id="T_7fc92_row0_col3" class="data row0 col3" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7fc92_level0_row1" class="row_heading level0 row1" >2 Black alone, Not Hispanic</th>
#       <td id="T_7fc92_row1_col0" class="data row1 col0" >62	 (6.8%)</td>
#       <td id="T_7fc92_row1_col1" class="data row1 col1" >37,357	 (12.9%)</td>
#       <td id="T_7fc92_row1_col2" class="data row1 col2" >37,419	 (12.9%)</td>
#       <td id="T_7fc92_row1_col3" class="data row1 col3" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7fc92_level0_row2" class="row_heading level0 row2" >3 American Indian and Alaska Native alone, Not Hispanic</th>
#       <td id="T_7fc92_row2_col0" class="data row2 col0" >4	 (0.4%)</td>
#       <td id="T_7fc92_row2_col1" class="data row2 col1" >1,101	 (0.4%)</td>
#       <td id="T_7fc92_row2_col2" class="data row2 col2" >1,105	 (0.4%)</td>
#       <td id="T_7fc92_row2_col3" class="data row2 col3" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_7fc92_level0_row3" class="row_heading level0 row3" >4 Asian alone, Not Hispanic</th>
#       <td id="T_7fc92_row3_col0" class="data row3 col0" >27	 (3.0%)</td>
#       <td id="T_7fc92_row3_col1" class="data row3 col1" >7,994	 (2.8%)</td>
#       <td id="T_7fc92_row3_col2" class="data row3 col2" >8,021	 (2.8%)</td>
#       <td id="T_7fc92_row3_col3" class="data row3 col3" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7fc92_level0_row4" class="row_heading level0 row4" >5 Other Race, Not Hispanic</th>
#       <td id="T_7fc92_row4_col0" class="data row4 col0" >2	 (0.2%)</td>
#       <td id="T_7fc92_row4_col1" class="data row4 col1" >2,929	 (1.0%)</td>
#       <td id="T_7fc92_row4_col2" class="data row4 col2" >2,931	 (1.0%)</td>
#       <td id="T_7fc92_row4_col3" class="data row4 col3" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_7fc92_level0_row5" class="row_heading level0 row5" >6 Any Race, Hispanic</th>
#       <td id="T_7fc92_row5_col0" class="data row5 col0" >66	 (7.3%)</td>
#       <td id="T_7fc92_row5_col1" class="data row5 col1" >61,071	 (21.1%)</td>
#       <td id="T_7fc92_row5_col2" class="data row5 col2" >61,137	 (21.1%)</td>
#       <td id="T_7fc92_row5_col3" class="data row5 col3" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_7fc92_level0_row6" class="row_heading level0 row6" >7 Group Quarters no Race Ethnicity Data</th>
#       <td id="T_7fc92_row6_col0" class="data row6 col0" >340	 (37.4%)</td>
#       <td id="T_7fc92_row6_col1" class="data row6 col1" >3,957	 (1.4%)</td>
#       <td id="T_7fc92_row6_col2" class="data row6 col2" >4,297	 (1.5%)</td>
#       <td id="T_7fc92_row6_col3" class="data row6 col3" >7.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7fc92_level0_row7" class="row_heading level0 row7" >Total</th>
#       <td id="T_7fc92_row7_col0" class="data row7 col0" >910	 (100.0%)</td>
#       <td id="T_7fc92_row7_col1" class="data row7 col1" >288,922	 (100.0%)</td>
#       <td id="T_7fc92_row7_col2" class="data row7 col2" >289,832	 (100.0%)</td>
#       <td id="T_7fc92_row7_col3" class="data row7 col3" >0.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
PopResultsTable.pop_results_table(hua_hui_gdf, 
                  who = "Total Population by Households", 
                  what = "by Race, Ethnicity",
                  where = where,
                  when = "2010",
                  row_index = "Group Quarters Type",
                  col_index = 'Building Data Availability_str',
                  row_percent = '0 Missing Building Data')
# Out:
# <style type="text/css">
# #T_2f477 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_2f477">
#   <caption>Table. Total Population by Households by Race, Ethnicity, Galveston, TX, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Building Data Availability_str</th>
#       <th id="T_2f477_level0_col0" class="col_heading level0 col0" >0 Missing Building Data (%)</th>
#       <th id="T_2f477_level0_col1" class="col_heading level0 col1" >1 Building Data Available (%)</th>
#       <th id="T_2f477_level0_col2" class="col_heading level0 col2" >Total Population by Households (%)</th>
#       <th id="T_2f477_level0_col3" class="col_heading level0 col3" >Percent Row
# 0 Missing Building Data</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Group Quarters Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f477_level0_row0" class="row_heading level0 row0" >0. NA (non-group quarters)</th>
#       <td id="T_2f477_row0_col0" class="data row0 col0" >570	 (62.6%)</td>
#       <td id="T_2f477_row0_col1" class="data row0 col1" >284,965	 (98.6%)</td>
#       <td id="T_2f477_row0_col2" class="data row0 col2" >285,535	 (98.5%)</td>
#       <td id="T_2f477_row0_col3" class="data row0 col3" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row1" class="row_heading level0 row1" >1 Correctional facilities for adults</th>
#       <td id="T_2f477_row1_col0" class="data row1 col0" >nan	 (nan%)</td>
#       <td id="T_2f477_row1_col1" class="data row1 col1" >1,611	 (0.6%)</td>
#       <td id="T_2f477_row1_col2" class="data row1 col2" >1,611	 (0.6%)</td>
#       <td id="T_2f477_row1_col3" class="data row1 col3" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row2" class="row_heading level0 row2" >2. Juvenile facilities</th>
#       <td id="T_2f477_row2_col0" class="data row2 col0" >29	 (3.2%)</td>
#       <td id="T_2f477_row2_col1" class="data row2 col1" >103	 (0.0%)</td>
#       <td id="T_2f477_row2_col2" class="data row2 col2" >132	 (0.0%)</td>
#       <td id="T_2f477_row2_col3" class="data row2 col3" >22.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row3" class="row_heading level0 row3" >3. Nursing facilities/Skilled-nursing facilities</th>
#       <td id="T_2f477_row3_col0" class="data row3 col0" >278	 (30.5%)</td>
#       <td id="T_2f477_row3_col1" class="data row3 col1" >900	 (0.3%)</td>
#       <td id="T_2f477_row3_col2" class="data row3 col2" >1,178	 (0.4%)</td>
#       <td id="T_2f477_row3_col3" class="data row3 col3" >23.6%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row4" class="row_heading level0 row4" >4. Other institutional facilities</th>
#       <td id="T_2f477_row4_col0" class="data row4 col0" >nan	 (nan%)</td>
#       <td id="T_2f477_row4_col1" class="data row4 col1" >7	 (0.0%)</td>
#       <td id="T_2f477_row4_col2" class="data row4 col2" >7	 (0.0%)</td>
#       <td id="T_2f477_row4_col3" class="data row4 col3" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row5" class="row_heading level0 row5" >5. College/University student housing</th>
#       <td id="T_2f477_row5_col0" class="data row5 col0" >nan	 (nan%)</td>
#       <td id="T_2f477_row5_col1" class="data row5 col1" >917	 (0.3%)</td>
#       <td id="T_2f477_row5_col2" class="data row5 col2" >917	 (0.3%)</td>
#       <td id="T_2f477_row5_col3" class="data row5 col3" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row6" class="row_heading level0 row6" >6. Military quarters</th>
#       <td id="T_2f477_row6_col0" class="data row6 col0" >nan	 (nan%)</td>
#       <td id="T_2f477_row6_col1" class="data row6 col1" >36	 (0.0%)</td>
#       <td id="T_2f477_row6_col2" class="data row6 col2" >36	 (0.0%)</td>
#       <td id="T_2f477_row6_col3" class="data row6 col3" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row7" class="row_heading level0 row7" >7. Other noninstitutional facilities</th>
#       <td id="T_2f477_row7_col0" class="data row7 col0" >33	 (3.6%)</td>
#       <td id="T_2f477_row7_col1" class="data row7 col1" >383	 (0.1%)</td>
#       <td id="T_2f477_row7_col2" class="data row7 col2" >416	 (0.1%)</td>
#       <td id="T_2f477_row7_col3" class="data row7 col3" >7.9%</td>
#     </tr>
#     <tr>
#       <th id="T_2f477_level0_row8" class="row_heading level0 row8" >Total</th>
#       <td id="T_2f477_row8_col0" class="data row8 col0" >910	 (100.0%)</td>
#       <td id="T_2f477_row8_col1" class="data row8 col1" >288,922	 (100.0%)</td>
#       <td id="T_2f477_row8_col2" class="data row8 col2" >289,832	 (100.0%)</td>
#       <td id="T_2f477_row8_col3" class="data row8 col3" >0.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
PopResultsTable.pop_results_table(hua_hui_gdf, 
                   who = "Median Household Income", 
                  what = "by Race, Ethnicity",
                  where = where,
                  when = "2010",
                  row_index = "Race Ethnicity",
                  col_index = 'Tenure Status')
# Out:
# <style type="text/css">
# #T_c1272 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_c1272">
#   <caption>Table. Median Household Income by Race, Ethnicity, Galveston, TX, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Tenure Status</th>
#       <th id="T_c1272_level0_col0" class="col_heading level0 col0" >1 Owner Occupied</th>
#       <th id="T_c1272_level0_col1" class="col_heading level0 col1" >2 Renter Occupied</th>
#       <th id="T_c1272_level0_col2" class="col_heading level0 col2" >Median Household Income</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race Ethnicity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1272_level0_row0" class="row_heading level0 row0" >1 White alone, Not Hispanic</th>
#       <td id="T_c1272_row0_col0" class="data row0 col0" >$78,688</td>
#       <td id="T_c1272_row0_col1" class="data row0 col1" >$56,319</td>
#       <td id="T_c1272_row0_col2" class="data row0 col2" >$72,487</td>
#     </tr>
#     <tr>
#       <th id="T_c1272_level0_row1" class="row_heading level0 row1" >2 Black alone, Not Hispanic</th>
#       <td id="T_c1272_row1_col0" class="data row1 col0" >$42,419</td>
#       <td id="T_c1272_row1_col1" class="data row1 col1" >$31,080</td>
#       <td id="T_c1272_row1_col2" class="data row1 col2" >$37,191</td>
#     </tr>
#     <tr>
#       <th id="T_c1272_level0_row2" class="row_heading level0 row2" >3 American Indian and Alaska Native alone, Not Hispanic</th>
#       <td id="T_c1272_row2_col0" class="data row2 col0" >$55,344</td>
#       <td id="T_c1272_row2_col1" class="data row2 col1" >$48,630</td>
#       <td id="T_c1272_row2_col2" class="data row2 col2" >$51,167</td>
#     </tr>
#     <tr>
#       <th id="T_c1272_level0_row3" class="row_heading level0 row3" >4 Asian alone, Not Hispanic</th>
#       <td id="T_c1272_row3_col0" class="data row3 col0" >$71,109</td>
#       <td id="T_c1272_row3_col1" class="data row3 col1" >$43,866</td>
#       <td id="T_c1272_row3_col2" class="data row3 col2" >$64,160</td>
#     </tr>
#     <tr>
#       <th id="T_c1272_level0_row4" class="row_heading level0 row4" >5 Other Race, Not Hispanic</th>
#       <td id="T_c1272_row4_col0" class="data row4 col0" >$59,184</td>
#       <td id="T_c1272_row4_col1" class="data row4 col1" >$50,653</td>
#       <td id="T_c1272_row4_col2" class="data row4 col2" >$56,363</td>
#     </tr>
#     <tr>
#       <th id="T_c1272_level0_row5" class="row_heading level0 row5" >6 Any Race, Hispanic</th>
#       <td id="T_c1272_row5_col0" class="data row5 col0" >$54,308</td>
#       <td id="T_c1272_row5_col1" class="data row5 col1" >$41,168</td>
#       <td id="T_c1272_row5_col2" class="data row5 col2" >$49,128</td>
#     </tr>
#     <tr>
#       <th id="T_c1272_level0_row6" class="row_heading level0 row6" >Total</th>
#       <td id="T_c1272_row6_col0" class="data row6 col0" >$69,781</td>
#       <td id="T_c1272_row6_col1" class="data row6 col1" >$46,305</td>
#       <td id="T_c1272_row6_col2" class="data row6 col2" >$61,807</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Validate the Housing Unit Allocation has worked
# Notice that the population count totals for the community
# should match (pretty closely) data collected for the 2010 Decennial Census.
# This can be confirmed by going to data.census.gov

# %%
countyfips = communities[community]['counties'][county]['FIPS Code']
countyfips
# Out:
# '48167'

# %%
print("Total Population by Race and Ethnicity:")
print(f"https://data.census.gov/cedsci/table?g=0500000US{countyfips}&tid=DECENNIALSF12010.P5")

print("Median Income by Race and Ethnicity:")
print(f"All Households: https://data.census.gov/cedsci/table?g=0500000US{countyfips}&tid=ACSDT5Y2012.B19013")
print(f"Black Households: https://data.census.gov/cedsci/table?g=0500000US{countyfips}&tid=ACSDT5Y2012.B19013B")
print(f"White, not Hispanic Households: https://data.census.gov/cedsci/table?g=0500000US{countyfips}&tid=ACSDT5Y2012.B19013H")
print(f"Hispanic Households: https://data.census.gov/cedsci/table?g=0500000US{countyfips}&tid=ACSDT5Y2012.B19013I")
# Out:
# Total Population by Race and Ethnicity:
# https://data.census.gov/cedsci/table?g=0500000US48167&tid=DECENNIALSF12010.P5
# Median Income by Race and Ethnicity:
# All Households: https://data.census.gov/cedsci/table?g=0500000US48167&tid=ACSDT5Y2012.B19013
# Black Households: https://data.census.gov/cedsci/table?g=0500000US48167&tid=ACSDT5Y2012.B19013B
# White, not Hispanic Households: https://data.census.gov/cedsci/table?g=0500000US48167&tid=ACSDT5Y2012.B19013H
# Hispanic Households: https://data.census.gov/cedsci/table?g=0500000US48167&tid=ACSDT5Y2012.B19013I

# %% [markdown]
# Differences in the housing unit allocation and the Census count may be due to differences between political boundaries and the building inventory. See Rosenheim et al 2019 for more details.
#
# The housing unit allocation, plus the building results will become the input for the social science models such as the population dislocation model.

# %% [markdown]
# ## Explore the HUA Results

# %%
# add race ethnicity to data frame
hua_hui_race_gdf = PopResultsTable.add_race_ethnicity_to_pop_df(hua_hui_gdf)

# %% [markdown]
# ### Save map

# %%
import contextily as cx # For adding basemap tiles to plot
import matplotlib.pyplot as plt # For plotting and making graphs

condition1 = "(hua_hui_race_gdf.race >= 1)"
place = 'Lumberton'
condition2 = f"(hua_hui_race_gdf.placeNAME10 == '{place}')"

condition_list = {1 : f"{condition1}",
                  2 : f"{condition1} & {condition2}" 
                } 

for item in condition_list.keys():
    condition =  condition_list[item]
    # Obtain data
    popdata = hua_hui_race_gdf.loc[eval(condition)].copy(deep=True)
    hua_data = popdata.to_crs(epsg=4326)

    # Set save file
    mapname = 'racedotmap'
    # save hua_hui_gdf to csv
    check_folder = f"{outputfolder}/{community}/06_Explore"
    output_filename = f'{mapname}_{community}_{place}'
    filepath = check_folder+"/"+output_filename

    ''' Need to sort out figure and axes
    # Set figure size (width, height) in inches
    #plt.figure(figsize = ( 14 , 12 ))
    plt.rcParams["figure.figsize"] = [11.00, 8.5]
    plt.rcParams["figure.autolayout"] = True

    # Figure Title
    by_label = "Race Ethnicity"
    who = f"Housing Unit Locations"
    what = f"by {by_label}"
    where = "Lumberton, NC"
    when = "2010"
    table_title = who +" "+ what+", \n "+ where +", "+ when +"."


    # Set title for figure
    plt.title( table_title, size = 18)

    notes = "notes here"
    plt.gcf().text(0, 0, notes, 
                            va = 'bottom', ha='left',
                            fontstyle='italic', size=6)
    '''

    plt.rcParams["figure.figsize"] = [11.00, 8.5]
    plt.rcParams["figure.autolayout"] = True
    
    # Plot the data
    ax = hua_data.plot(column='Race Ethnicity',
                        categorical=True, 
                        legend=True, 
                        markersize = 0.05)
    cx.add_basemap(ax, crs = hua_data.crs, 
            source=cx.providers.Stamen.TonerLite)
    cx.add_basemap(ax, crs = hua_data.crs, 
            source=cx.providers.Stamen.TonerLabels)

    ax.figure.savefig(filepath+'v2.svg', 
                bbox_inches="tight",format = 'svg', 
                dpi=600)

    ax.figure.savefig(filepath+'v2.png', 
                bbox_inches="tight",format = 'png', 
                dpi=600)
